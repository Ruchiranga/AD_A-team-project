# %%
import re
import ast
import time
import requests
import pandas as pd
import numpy as np
import os.path
import urllib.request
import concurrent.futures
from os import listdir
from stem import Signal
from requests import get
from bs4 import BeautifulSoup
from datetime import datetime
from os.path import isfile, join
from stem.control import Controller

# %%
movie_subset = pd.read_pickle("./pickles/complete_178118.pkl")
movie_subset.head()
# Out:
#       tconst                              stars  oscarWins  nominations  wins  \
# 0  tt0014799  [nm0265550, nm0370407, nm0550195]          0            0     0
# 1  tt0014843  [nm0427659, nm0107574, nm0421138]          0            0     0
# 2  tt0014809  [nm0267916, nm0119572, nm0055809]          0            0     0
# 3  tt0014751             [nm0403710, nm0744408]          0            0     0
# 4  tt0014812  [nm0556953, nm0531962, nm0645941]          0            0     0
#
#   releaseDate releaseCountry plotKeywords budget worldwideGross metascore  \
# 0  1924-05-31             UK           []   None           None      None
# 1  1924-08-24            USA           []   None           None      None
# 2  1924-04-08            USA           []   None           None      None
# 3        None           None           []   None           None      None
# 4  1924-12-28            USA           []   None           None      None
#
#   musicProducer
# 0          None
# 1          None
# 2          None
# 3          None
# 4          None

# %%
stars_exploded = movie_subset.explode('stars')[['tconst', 'stars']]
stars_exploded.head()
# Out:
#       tconst      stars
# 0  tt0014799  nm0265550
# 0  tt0014799  nm0370407
# 0  tt0014799  nm0550195
# 1  tt0014843  nm0427659
# 1  tt0014843  nm0107574

# %%
stars_exploded.stars.nunique()
# Out:
# 138245

# %%
stars_counts = stars_exploded\
                    .groupby('stars')\
                    .count()\
                    .rename(columns={"tconst": "count"})\
                    .sort_values(['count'], ascending=False)
stars_counts.index.name = 'nconst'

# %%
stars_counts.tail(87400)
# Out:
#            count
# nconst
# nm0323379      2
# nm0098627      2
# nm0073596      2
# nm1054406      1
# nm1030940      1
# ...          ...
# nm0670816      1
# nm0163019      1
# nm0670779      1
# nm0670771      1
# nm9989884      1
#
# [87400 rows x 1 columns]

# %% [markdown]
# Close to 90000 stars have starred in only 1 movie in the chosen movie subset. For the purpose of bringing down the actors count for scraping,  for the moment, let's consider only the actors that have starred in more than 1 movie in the chosen movie subset.

# %%
print("Jessica Alba: {0} movies".format(stars_counts.loc['nm0004695']['count']))
print("Billy Boyd (Pippin from LOTR): {0} movies".format(stars_counts.loc['nm0101710']['count']))
print("Will Smith: {0} movies".format(stars_counts.loc['nm0000226']['count']))
print("Morgan Freeman: {0} movies".format(stars_counts.loc['nm0000151']['count']))
# Out:
# Jessica Alba: 4 movies
# Billy Boyd (Pippin from LOTR): 1 movies
# Will Smith: 12 movies
# Morgan Freeman: 26 movies

# %%
stars_subset = stars_counts[stars_counts['count'] > 1]
len(stars_subset)
# Out:
# 50848

# %% [markdown]
# ### Scraping

# %%
def get_tor_session(prev_session):
    session = requests.session()
    # Tor uses the 9050 port as the default socks port
    session.proxies = {'http':  'socks5://127.0.0.1:9050',
                       'https': 'socks5://127.0.0.1:9050'}
    return session

def renew_connection():
    with Controller.from_port(port = 9051) as controller:
        controller.authenticate(password="password")

def get_data(session, url):
    nconst=url.rsplit('/', 2)[-2]
    result = {
        'nconst': nconst,
        'year': None,
        'category': None,
        'w_n': None,
        'description': None,
        'movie': None,
        'tconst': None 
    }
    
    with session.get(url) as req:
        req.raise_for_status()    
    
        body=req.text

        soup=BeautifulSoup(body,'html.parser')
        awards=soup.find_all('tr')
        if awards is not None:
            for award in awards:
                if award.find('td', class_='award_year') is not None:
                    if award.find('td', class_='award_year').find('a') is not None:
                        year = award.find('td', class_='award_year').find('a').text
                        if year is not None:
                            try:
                                year = int(year.replace("\n", "").strip())
                                result['year'] = year
                            except:
                                print("Failed to parse int year {0}".format(year))



                if award.find('span',class_='award_category') is not None:
                    result['category'] = award.find('span',class_='award_category').text

                if award.find('td',class_="award_outcome") is not None:
                    outcome = award.find('td',class_="award_outcome").find('b')
                    if outcome is not None:
                        outcome_txt = outcome.text
                        if outcome_txt is not None:
                            result['w_n'] = outcome_txt.replace("\n", "").strip()

                if award.find('td', class_='award_description') is not None:
                    award_txt = award.find('td',class_='award_description').find(text=True, recursive=False)
                    award_info = award.find('td',class_='award_description').find('a')
                    if award_txt is not None:
                        result['description'] = award_txt.replace("\n", "").strip()

                    if award_info is not None:
                        result['movie'] = award_info.text
                        tconst_res = re.search('tt\d{7}', award_info.get('href'))
                        if tconst_res is not None:
                            result['tconst'] = tconst_res.group(0)

            return result

# %%
# Set the start index and end index. Ip is renewed after each chunk of urls of 'step_size'. 
# After every chunk, result is written to a pickle. So if you need to stop the execution in the middle, note the
# index range of the last successfully written pickle file (from the printed logs) and use the remaining range
# for start and end index to resume from where you stopped.
postfix = 'actors_subset'
s_idx = 0
e_idx = len(stars_subset)
step_size = 5000
pickles_save_dir = './pickles/{0}'.format(postfix)

base_url = 'https://www.imdb.com/name/{0}/awards'
urls=[]
for nconst in stars_subset.index[s_idx:e_idx]:
    urls.append(base_url.format(nconst))

used_ips = []
failed_urls = []

with concurrent.futures.ThreadPoolExecutor(max_workers=150) as executor:
#     session = get_tor_session(None)
    chunk_indeces = np.arange(0, len(urls), step_size)
    
    for idx, start in enumerate(chunk_indeces, start=1):
        start_t = time.time()
        finals = []
        renew_connection()
        
        new_ip = ''
        with requests.session() as session:
        # Tor uses the 9050 port as the default socks port
            session.proxies = {'http':  'socks5://127.0.0.1:9050',
                               'https': 'socks5://127.0.0.1:9050'}
#             session = get_tor_session(session)
            new_ip = ast.literal_eval(session.get("http://httpbin.org/ip").text)["origin"].split(",")[0]
        while new_ip in used_ips:
            print("Renewed IP {0} already used. Waiting 5s to renew...".format(new_ip))
            time.sleep(5)
            renew_connection()
            with requests.session() as session:
                session.proxies = {'http':  'socks5://127.0.0.1:9050',
                                   'https': 'socks5://127.0.0.1:9050'}
#             session = get_tor_session(session)
                new_ip = ast.literal_eval(session.get("http://httpbin.org/ip").text)["origin"].split(",")[0]
        used_ips.append(new_ip)

        url_chunk = urls[start:start + step_size] + failed_urls
        failed_urls = []

        with requests.session() as session:
            session.proxies = {'http':  'socks5://127.0.0.1:9050',
                                   'https': 'socks5://127.0.0.1:9050'}
            future_to_url = {executor.submit(get_data, session, url): url for url in url_chunk}
            for future in concurrent.futures.as_completed(future_to_url):
                url = future_to_url[future]
                try:
                    data = future.result()
                    finals.append(data)
                except Exception as exc:
                    failed_urls.append(url.strip("'"))
                    print('%s generated an exception: %s. Added to retry list.' % (url, exc))

            concurrent.futures.wait(
                list(future_to_url.keys()), 
                timeout=None, 
                return_when=concurrent.futures.ALL_COMPLETED)
            end_t = time.time()
            print("chunk {0} of {1} completed with IP {2}. Took {3} seconds."\
                  .format(idx, len(chunk_indeces), new_ip, end_t - start_t))   
            actors_df = pd.DataFrame(data=finals)
            if not os.path.exists(pickles_save_dir):
                os.makedirs(pickles_save_dir)
            pickle_path = "{4}/{0}_{1}-{2}_{3}.pkl"\
                            .format(idx, start, start + step_size, postfix, pickles_save_dir)
            actors_df.to_pickle(pickle_path)
            print("Wrote pickle {0} with {1} rows".format(pickle_path, len(actors_df)))
        
    if len(failed_urls) > 0:
        print('\n\n\n\n!!!**********************************!!!')
        print('Failed to retrieve the following URLs.\n')
        print(failed_urls)
        print('\n!!!**********************************!!!')
        print('Note: Run the following cell to retry the failed urls')
    else:
        print("\n\n\n\n!!!**********************************!!!\n")
        print("Scraping succeeded!")
        print('\n!!!**********************************!!!')
        print('''Note: Next, run the script that combine all pickles''')
# Out:
# https://www.imdb.com/name/nm0249982/awards generated an exception: [('system library', 'fopen', 'Too many open files'), ('BIO routines', 'BIO_new_file', 'system lib'), ('x509 certificate routines', 'X509_load_cert_crl_file', 'system lib')]. Added to retry list.
# https://www.imdb.com/name/nm0823633/awards generated an exception: [('system library', 'fopen', 'Too many open files'), ('BIO routines', 'BIO_new_file', 'system lib'), ('x509 certificate routines', 'X509_load_cert_crl_file', 'system lib')]. Added to retry list.
# https://www.imdb.com/name/nm0453520/awards generated an exception: [('system library', 'fopen', 'Too many open files'), ('BIO routines', 'BIO_new_file', 'system lib'), ('x509 certificate routines', 'X509_load_cert_crl_file', 'system lib')]. Added to retry list.
# https://www.imdb.com/name/nm0004437/awards generated an exception: [('system library', 'fopen', 'Too many open files'), ('BIO routines', 'BIO_new_file', 'system lib'), ('x509 certificate routines', 'X509_load_cert_crl_file', 'system lib')]. Added to retry list.
# https://www.imdb.com/name/nm0369058/awards generated an exception: [('system library', 'fopen', 'Too many open files'), ('BIO routines', 'BIO_new_file', 'system lib'), ('x509 certificate routines', 'X509_load_cert_crl_file', 'system lib')]. Added to retry list.
# https://www.imdb.com/name/nm0004462/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0004462/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x1202c6b38>: Failed to establish a new connection: [Errno 24] Too many open files',)). Added to retry list.
# https://www.imdb.com/name/nm0000053/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0000053/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x12029fd68>: Failed to establish a new connection: [Errno 24] Too many open files',)). Added to retry list.
# https://www.imdb.com/name/nm0000367/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0000367/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x11f40be10>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)). Added to retry list.
# https://www.imdb.com/name/nm0201638/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0201638/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x12146e668>: Failed to establish a new connection: [Errno 24] Too many open files',)). Added to retry list.
# https://www.imdb.com/name/nm0000818/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0000818/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x11a9c1fd0>: Failed to establish a new connection: [Errno 24] Too many open files',)). Added to retry list.
# https://www.imdb.com/name/nm0800302/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0800302/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x1202ae0b8>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)). Added to retry list.
# https://www.imdb.com/name/nm0849011/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0849011/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x12029f9b0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)). Added to retry list.
# https://www.imdb.com/name/nm0874781/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0874781/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x11f52f9e8>: Failed to establish a new connection: [Errno 24] Too many open files',)). Added to retry list.
# https://www.imdb.com/name/nm0674741/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0674741/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x11f52fbe0>: Failed to establish a new connection: [Errno 24] Too many open files',)). Added to retry list.
# https://www.imdb.com/name/nm0221488/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0221488/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x11f549128>: Failed to establish a new connection: [Errno 24] Too many open files',)). Added to retry list.
# https://www.imdb.com/name/nm0214150/awards generated an exception: [('system library', 'fopen', 'Too many open files'), ('BIO routines', 'BIO_new_file', 'system lib'), ('x509 certificate routines', 'X509_load_cert_crl_file', 'system lib')]. Added to retry list.
# https://www.imdb.com/name/nm0316995/awards generated an exception: [('system library', 'fopen', 'Too many open files'), ('BIO routines', 'BIO_new_file', 'system lib'), ('x509 certificate routines', 'X509_load_cert_crl_file', 'system lib')]. Added to retry list.
# https://www.imdb.com/name/nm0001120/awards generated an exception: [('system library', 'fopen', 'Too many open files'), ('BIO routines', 'BIO_new_file', 'system lib'), ('x509 certificate routines', 'X509_load_cert_crl_file', 'system lib')]. Added to retry list.
# https://www.imdb.com/name/nm0712660/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0712660/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x11f549940>: Failed to establish a new connection: [Errno 24] Too many open files',)). Added to retry list.
# https://www.imdb.com/name/nm0802374/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0802374/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x11f549860>: Failed to establish a new connection: [Errno 24] Too many open files',)). Added to retry list.
# https://www.imdb.com/name/nm0000051/awards generated an exception: [('system library', 'fopen', 'Too many open files'), ('BIO routines', 'BIO_new_file', 'system lib'), ('x509 certificate routines', 'X509_load_cert_crl_file', 'system lib')]. Added to retry list.
# https://www.imdb.com/name/nm1066548/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm1066548/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x11f549cc0>: Failed to establish a new connection: [Errno 24] Too many open files',)). Added to retry list.
# https://www.imdb.com/name/nm0101071/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0101071/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x12146e8d0>: Failed to establish a new connection: [Errno 24] Too many open files',)). Added to retry list.
# https://www.imdb.com/name/nm0254381/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0254381/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x11f556198>: Failed to establish a new connection: [Errno 24] Too many open files',)). Added to retry list.
# https://www.imdb.com/name/nm0004334/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0004334/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x11f5566d8>: Failed to establish a new connection: [Errno 24] Too many open files',)). Added to retry list.
# https://www.imdb.com/name/nm0001766/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0001766/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x11f556908>: Failed to establish a new connection: [Errno 24] Too many open files',)). Added to retry list.
# https://www.imdb.com/name/nm0001076/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0001076/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x11f5491d0>: Failed to establish a new connection: [Errno 24] Too many open files',)). Added to retry list.
# https://www.imdb.com/name/nm0626259/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0626259/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x11f56d1d0>: Failed to establish a new connection: [Errno 24] Too many open files',)). Added to retry list.
# https://www.imdb.com/name/nm0721073/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0721073/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x11f56d080>: Failed to establish a new connection: [Errno 24] Too many open files',)). Added to retry list.
# https://www.imdb.com/name/nm0320760/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0320760/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x11f56d438>: Failed to establish a new connection: [Errno 24] Too many open files',)). Added to retry list.
# https://www.imdb.com/name/nm0084435/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0084435/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x11f56d0f0>: Failed to establish a new connection: [Errno 24] Too many open files',)). Added to retry list.
# https://www.imdb.com/name/nm0785664/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0785664/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x11f56dcf8>: Failed to establish a new connection: [Errno 24] Too many open files',)). Added to retry list.
# https://www.imdb.com/name/nm0419685/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0419685/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x11f5567f0>: Failed to establish a new connection: [Errno 24] Too many open files',)). Added to retry list.
# https://www.imdb.com/name/nm0018437/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0018437/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x11f56dba8>: Failed to establish a new connection: [Errno 24] Too many open files',)). Added to retry list.
# https://www.imdb.com/name/nm0534045/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0534045/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x11f56dda0>: Failed to establish a new connection: [Errno 24] Too many open files',)). Added to retry list.
# https://www.imdb.com/name/nm0869451/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0869451/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x11f5862e8>: Failed to establish a new connection: [Errno 24] Too many open files',)). Added to retry list.
# https://www.imdb.com/name/nm0764762/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0764762/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x11f56d668>: Failed to establish a new connection: [Errno 24] Too many open files',)). Added to retry list.
# https://www.imdb.com/name/nm0122470/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0122470/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x11f586908>: Failed to establish a new connection: [Errno 24] Too many open files',)). Added to retry list.
# https://www.imdb.com/name/nm0729473/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0729473/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x1202bd080>: Failed to establish a new connection: [Errno 24] Too many open files',)). Added to retry list.
# https://www.imdb.com/name/nm0000012/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0000012/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x1202c6a20>: Failed to establish a new connection: [Errno 24] Too many open files',)). Added to retry list.
# https://www.imdb.com/name/nm0000802/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0000802/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x11f586ac8>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)). Added to retry list.
# https://www.imdb.com/name/nm0148974/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0148974/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x11f599668>: Failed to establish a new connection: [Errno 24] Too many open files',)). Added to retry list.
# https://www.imdb.com/name/nm0015000/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0015000/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x11f586b38>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)). Added to retry list.
# https://www.imdb.com/name/nm0701633/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0701633/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x11f599438>: Failed to establish a new connection: [Errno 24] Too many open files',)). Added to retry list.
# https://www.imdb.com/name/nm0853604/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0853604/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x11f5992b0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)). Added to retry list.
# https://www.imdb.com/name/nm0107574/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0107574/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x11f599518>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)). Added to retry list.
# https://www.imdb.com/name/nm0799108/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0799108/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x11f5991d0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)). Added to retry list.
# https://www.imdb.com/name/nm0185568/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0185568/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x11f5b6940>: Failed to establish a new connection: [Errno 24] Too many open files',)). Added to retry list.
# https://www.imdb.com/name/nm0358076/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0358076/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x11f5b6470>: Failed to establish a new connection: [Errno 24] Too many open files',)). Added to retry list.
# https://www.imdb.com/name/nm0000472/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0000472/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x11f5b6898>: Failed to establish a new connection: [Errno 24] Too many open files',)). Added to retry list.
# https://www.imdb.com/name/nm0002154/awards generated an exception: [('system library', 'fopen', 'Too many open files'), ('BIO routines', 'BIO_new_file', 'system lib'), ('x509 certificate routines', 'X509_load_cert_crl_file', 'system lib')]. Added to retry list.
# https://www.imdb.com/name/nm0406737/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0406737/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x11f5b6fd0>: Failed to establish a new connection: [Errno 24] Too many open files',)). Added to retry list.
# https://www.imdb.com/name/nm0272794/awards generated an exception: [('system library', 'fopen', 'Too many open files'), ('BIO routines', 'BIO_new_file', 'system lib'), ('x509 certificate routines', 'X509_load_cert_crl_file', 'system lib')]. Added to retry list.
# https://www.imdb.com/name/nm0001935/awards generated an exception: [('system library', 'fopen', 'Too many open files'), ('BIO routines', 'BIO_new_file', 'system lib'), ('x509 certificate routines', 'X509_load_cert_crl_file', 'system lib')]. Added to retry list.
# https://www.imdb.com/name/nm0113902/awards generated an exception: [('system library', 'fopen', 'Too many open files'), ('BIO routines', 'BIO_new_file', 'system lib'), ('x509 certificate routines', 'X509_load_cert_crl_file', 'system lib')]. Added to retry list.
# https://www.imdb.com/name/nm0295992/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0295992/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x11f5b62e8>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)). Added to retry list.
# https://www.imdb.com/name/nm0107575/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0107575/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x11f5c9f98>: Failed to establish a new connection: [Errno 24] Too many open files',)). Added to retry list.
# https://www.imdb.com/name/nm0363218/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0363218/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x11f5ed710>: Failed to establish a new connection: [Errno 24] Too many open files',)). Added to retry list.
# https://www.imdb.com/name/nm0529876/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0529876/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x11f5db668>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)). Added to retry list.
# https://www.imdb.com/name/nm0006763/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0006763/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x11f5db400>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)). Added to retry list.
# https://www.imdb.com/name/nm0098376/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0098376/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x11f5dbcc0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)). Added to retry list.
# https://www.imdb.com/name/nm0199087/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0199087/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x11f5c9a58>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)). Added to retry list.
# https://www.imdb.com/name/nm0556953/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0556953/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x11f5db9e8>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)). Added to retry list.
# https://www.imdb.com/name/nm0812929/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0812929/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x11f5fab00>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)). Added to retry list.
# https://www.imdb.com/name/nm0001229/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0001229/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x11f5fa8d0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)). Added to retry list.
# https://www.imdb.com/name/nm0207023/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0207023/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x11f5faba8>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)). Added to retry list.
# https://www.imdb.com/name/nm0000784/awards generated an exception: [('system library', 'fopen', 'Too many open files'), ('BIO routines', 'BIO_new_file', 'system lib'), ('x509 certificate routines', 'X509_load_cert_crl_file', 'system lib')]. Added to retry list.
# https://www.imdb.com/name/nm0035159/awards generated an exception: [('system library', 'fopen', 'Too many open files'), ('BIO routines', 'BIO_new_file', 'system lib'), ('x509 certificate routines', 'X509_load_cert_crl_file', 'system lib')]. Added to retry list.
# https://www.imdb.com/name/nm0367928/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0367928/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x11f60efd0>: Failed to establish a new connection: [Errno 24] Too many open files',)). Added to retry list.
# https://www.imdb.com/name/nm0288003/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0288003/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x11f61d0f0>: Failed to establish a new connection: [Errno 24] Too many open files',)). Added to retry list.
# https://www.imdb.com/name/nm0893449/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0893449/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x11f5dbf98>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)). Added to retry list.
# https://www.imdb.com/name/nm0000897/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0000897/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x11f60ef28>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)). Added to retry list.
# https://www.imdb.com/name/nm0000440/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0000440/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x11f62b080>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)). Added to retry list.
# https://www.imdb.com/name/nm0603875/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0603875/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x11f61db38>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)). Added to retry list.
# https://www.imdb.com/name/nm0001870/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0001870/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x11f61d828>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)). Added to retry list.
# https://www.imdb.com/name/nm0301556/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0301556/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x11f6393c8>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)). Added to retry list.
# https://www.imdb.com/name/nm0089524/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0089524/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x11f5fa860>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)). Added to retry list.
# https://www.imdb.com/name/nm0848910/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0848910/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x11f5db240>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)). Added to retry list.
# https://www.imdb.com/name/nm0000313/awards generated an exception: [('system library', 'fopen', 'Too many open files'), ('BIO routines', 'BIO_new_file', 'system lib'), ('x509 certificate routines', 'X509_load_cert_crl_file', 'system lib')]. Added to retry list.
# https://www.imdb.com/name/nm0007042/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0007042/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x123142390>: Failed to establish a new connection: [Errno 24] Too many open files',)). Added to retry list.
# https://www.imdb.com/name/nm0373535/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0373535/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x1234ebc88>: Failed to establish a new connection: [Errno 24] Too many open files',)). Added to retry list.
# https://www.imdb.com/name/nm0085038/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0085038/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x12682a9b0>: Failed to establish a new connection: [Errno 24] Too many open files',)). Added to retry list.
# https://www.imdb.com/name/nm0113873/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0113873/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x120838cf8>: Failed to establish a new connection: [Errno 24] Too many open files',)). Added to retry list.
# https://www.imdb.com/name/nm0000072/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0000072/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x123492320>: Failed to establish a new connection: [Errno 24] Too many open files',)). Added to retry list.
# https://www.imdb.com/name/nm0299885/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0299885/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x12331ebe0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)). Added to retry list.
# https://www.imdb.com/name/nm0156484/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0156484/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x1234c2908>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)). Added to retry list.
# https://www.imdb.com/name/nm0002011/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0002011/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x11aafcb70>: Failed to establish a new connection: [Errno 24] Too many open files',)). Added to retry list.
# https://www.imdb.com/name/nm0350324/awards generated an exception: [('system library', 'fopen', 'Too many open files'), ('BIO routines', 'BIO_new_file', 'system lib'), ('x509 certificate routines', 'X509_load_cert_crl_file', 'system lib')]. Added to retry list.
# https://www.imdb.com/name/nm0000164/awards generated an exception: [('system library', 'fopen', 'Too many open files'), ('BIO routines', 'BIO_new_file', 'system lib'), ('x509 certificate routines', 'X509_load_cert_crl_file', 'system lib')]. Added to retry list.
# https://www.imdb.com/name/nm0052333/awards generated an exception: [('system library', 'fopen', 'Too many open files'), ('BIO routines', 'BIO_new_file', 'system lib'), ('x509 certificate routines', 'X509_load_cert_crl_file', 'system lib')]. Added to retry list.
# https://www.imdb.com/name/nm0624470/awards generated an exception: [('system library', 'fopen', 'Too many open files'), ('BIO routines', 'BIO_new_file', 'system lib'), ('x509 certificate routines', 'X509_load_cert_crl_file', 'system lib')]. Added to retry list.
# https://www.imdb.com/name/nm0016290/awards generated an exception: [('system library', 'fopen', 'Too many open files'), ('BIO routines', 'BIO_new_file', 'system lib'), ('x509 certificate routines', 'X509_load_cert_crl_file', 'system lib')]. Added to retry list.
# https://www.imdb.com/name/nm0401368/awards generated an exception: [('system library', 'fopen', 'Too many open files'), ('BIO routines', 'BIO_new_file', 'system lib'), ('x509 certificate routines', 'X509_load_cert_crl_file', 'system lib')]. Added to retry list.
# https://www.imdb.com/name/nm0155546/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0155546/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x1234137f0>: Failed to establish a new connection: [Errno 24] Too many open files',)). Added to retry list.
# https://www.imdb.com/name/nm0394472/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0394472/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x124fc4320>: Failed to establish a new connection: [Errno 24] Too many open files',)). Added to retry list.
# https://www.imdb.com/name/nm0260020/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0260020/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x1234c2630>: Failed to establish a new connection: [Errno 24] Too many open files',)). Added to retry list.
# https://www.imdb.com/name/nm0475610/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0475610/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x124fc4b70>: Failed to establish a new connection: [Errno 24] Too many open files',)). Added to retry list.
# https://www.imdb.com/name/nm0245304/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0245304/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x124fc44e0>: Failed to establish a new connection: [Errno 24] Too many open files',)). Added to retry list.
# https://www.imdb.com/name/nm0560962/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0560962/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x121261cc0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)). Added to retry list.
# https://www.imdb.com/name/nm0520595/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0520595/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x1212616a0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)). Added to retry list.
# https://www.imdb.com/name/nm1135609/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm1135609/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x122df6ac8>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)). Added to retry list.
# https://www.imdb.com/name/nm0259816/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0259816/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x123413240>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)). Added to retry list.
# https://www.imdb.com/name/nm0062428/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0062428/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x121261940>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)). Added to retry list.
# https://www.imdb.com/name/nm0001805/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0001805/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x120365550>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)). Added to retry list.
# https://www.imdb.com/name/nm0619798/awards generated an exception: [('system library', 'fopen', 'Too many open files'), ('BIO routines', 'BIO_new_file', 'system lib'), ('x509 certificate routines', 'X509_load_cert_crl_file', 'system lib')]. Added to retry list.
# https://www.imdb.com/name/nm0562920/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0562920/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x120f81ba8>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)). Added to retry list.
# https://www.imdb.com/name/nm0354878/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0354878/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x11f66ce80>: Failed to establish a new connection: [Errno 24] Too many open files',)). Added to retry list.
# https://www.imdb.com/name/nm0363104/awards generated an exception: [('system library', 'fopen', 'Too many open files'), ('BIO routines', 'BIO_new_file', 'system lib'), ('x509 certificate routines', 'X509_load_cert_crl_file', 'system lib')]. Added to retry list.
# https://www.imdb.com/name/nm0014351/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0014351/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x125d3eb70>: Failed to establish a new connection: [Errno 24] Too many open files',)). Added to retry list.
# https://www.imdb.com/name/nm0850236/awards generated an exception: [('system library', 'fopen', 'Too many open files'), ('BIO routines', 'BIO_new_file', 'system lib'), ('x509 certificate routines', 'X509_load_cert_crl_file', 'system lib')]. Added to retry list.
# https://www.imdb.com/name/nm0016754/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0016754/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x11f66c860>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)). Added to retry list.
# https://www.imdb.com/name/nm0015081/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0015081/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x1299f8978>: Failed to establish a new connection: [Errno 24] Too many open files',)). Added to retry list.
# https://www.imdb.com/name/nm0226158/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0226158/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x125d3ea20>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)). Added to retry list.
# https://www.imdb.com/name/nm0275428/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0275428/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x1299f8630>: Failed to establish a new connection: [Errno 24] Too many open files',)). Added to retry list.
# https://www.imdb.com/name/nm0792911/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0792911/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x1205b61d0>: Failed to establish a new connection: [Errno 24] Too many open files',)). Added to retry list.
# https://www.imdb.com/name/nm0015293/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0015293/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x1299f8438>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)). Added to retry list.
# https://www.imdb.com/name/nm0001336/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0001336/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x1299f8be0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)). Added to retry list.
# https://www.imdb.com/name/nm0300623/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0300623/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x1205b6da0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)). Added to retry list.
# https://www.imdb.com/name/nm0034301/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0034301/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x1205b6dd8>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)). Added to retry list.
# https://www.imdb.com/name/nm0473314/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0473314/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x1299f8b38>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)). Added to retry list.
# https://www.imdb.com/name/nm0002013/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0002013/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x1205b6470>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)). Added to retry list.
# https://www.imdb.com/name/nm0000086/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0000086/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x12647de10>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)). Added to retry list.
# https://www.imdb.com/name/nm0002001/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0002001/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x12647dc88>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)). Added to retry list.
# https://www.imdb.com/name/nm0000197/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0000197/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x12647de48>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)). Added to retry list.
# https://www.imdb.com/name/nm0904303/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0904303/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x1274d4a90>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)). Added to retry list.
# https://www.imdb.com/name/nm0708048/awards generated an exception: SOCKSHTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /name/nm0708048/awards (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x125d3ef98>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)). Added to retry list.
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "<ipython-input-10-c91b4a8ee5a8>", line 53, in <module>
#     for future in concurrent.futures.as_completed(future_to_url):
#   File "/Users/ruchiranga/anaconda3/lib/python3.6/concurrent/futures/_base.py", line 240, in as_completed
#     waiter.event.wait(wait_timeout)
#   File "/Users/ruchiranga/anaconda3/lib/python3.6/threading.py", line 551, in wait
#     signaled = self._cond.wait(timeout)
#   File "/Users/ruchiranga/anaconda3/lib/python3.6/threading.py", line 295, in wait
#     waiter.acquire()
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/ruchiranga/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3326, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-10-c91b4a8ee5a8>", line 87, in <module>
#     print('''Note: Next, run the script that combine all pickles''')
#   File "/Users/ruchiranga/anaconda3/lib/python3.6/concurrent/futures/_base.py", line 611, in __exit__
#     self.shutdown(wait=True)
#   File "/Users/ruchiranga/anaconda3/lib/python3.6/concurrent/futures/thread.py", line 152, in shutdown
#     t.join()
#   File "/Users/ruchiranga/anaconda3/lib/python3.6/threading.py", line 1056, in join
#     self._wait_for_tstate_lock()
#   File "/Users/ruchiranga/anaconda3/lib/python3.6/threading.py", line 1072, in _wait_for_tstate_lock
#     elif lock.acquire(block, timeout):
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/ruchiranga/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2040, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/ruchiranga/anaconda3/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/ruchiranga/anaconda3/lib/python3.6/site-packages/IPython/core/ultratb.py", line 319, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/ruchiranga/anaconda3/lib/python3.6/site-packages/IPython/core/ultratb.py", line 353, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
# ...
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com--- Logging error ---
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.imdb.com

# %%
'''
Run the following script only if there were any failed URLS at the end of the previous script execution.
Run this several times if you still see failures until there are none. But if some dont succeed even 
after multiple attempts, its probably a problem on imdb side and we can just ignore them.
'''
# urls = failed_urls

# if len(urls) > 0:
#     retry_failed_urls = []

#     with concurrent.futures.ThreadPoolExecutor(max_workers=150) as executor:
#         session = get_tor_session(None)
#         chunk_indeces = np.arange(0, len(urls), step_size)

#         for idx, start in enumerate(chunk_indeces, start=1):
#             start_t = time.time()
#             finals = []
#             renew_connection()
#             session = get_tor_session(session)
#             new_ip = ast.literal_eval(session.get("http://httpbin.org/ip").text)["origin"].split(",")[0]
#             while new_ip in used_ips:
#                 print("Renewed IP {0} already used. Waiting 5s to renew...".format(new_ip))
#                 time.sleep(5)
#                 renew_connection()
#                 session = get_tor_session(session)
#                 new_ip = ast.literal_eval(session.get("http://httpbin.org/ip").text)["origin"].split(",")[0]
#             used_ips.append(new_ip)

#             url_chunk = urls[start:start + step_size] + retry_failed_urls
#             retry_failed_urls = []

#             future_to_url = {executor.submit(get_data, session, url): url for url in url_chunk}
#             for future in concurrent.futures.as_completed(future_to_url):
#                 url = future_to_url[future]
#                 try:
#                     data = future.result()
#                     finals.append(data)
#                 except Exception as exc:
#                     retry_failed_urls.append(url.strip("'"))
#                     print('%s generated an exception: %s. Added to retry list.' % (url, exc))

#             concurrent.futures.wait(list(future_to_url.keys()), timeout=None, return_when=concurrent.futures.ALL_COMPLETED)
#             end_t = time.time()
#             print("chunk {0} of {1} completed with IP {2}. Took {3} seconds.".format(idx, len(chunk_indeces), new_ip, end_t - start_t))   
#             actors_df = pd.DataFrame(data=finals)
#             if len(actors_df) > 0:
#                 pickle_path = "./pickles/actortor/{0}_{1}-{2}_{3}_retry.pkl".format(idx, start, start + step_size, postfix)
#                 actors_df.to_pickle(pickle_path)
#                 print("Wrote pickle {0} with {1} rows".format(pickle_path, len(actors_df)))

#         if len(retry_failed_urls) > 0:
#             print('\n\n\n\n!!!**********************************!!!')
#             print('Retry failed with the following URLs.\n')
#             print(retry_failed_urls)
#             print('\n!!!**********************************!!!')
#             print('Note: Run this script several times to see if all succeed.',
#             'If some dont, it probably means they wont ever. so just give them up.')
#         else:
#             print("\n\n\n\n!!!**********************************!!!\n")
#             print("Retry succeeded!")
#             print('\n!!!**********************************!!!')
#             print('''Note: Run the following script to combine all pickles''')

# %%
# Combine the created pickles into one Dataframe
# Ignore any sytem files starting with . or folders if any
pickles = [f for f in listdir(pickles_save_dir) if isfile(join(dir_path, f)) and not f.startswith('.')]

dfs = list(map(lambda x: pd.read_pickle("{0}/{1}".format(dir_path,x)), pickles))
combined_df = pd.concat(dfs)
combined_df.reset_index(drop=True, inplace=True)
if not os.path.exists('./pickles'):
    os.makedirs('./pickles')
combined_df.to_pickle("./pickles/complete_{1}_{0}.pkl".format(e_idx, postfix))
len(combined_df)
