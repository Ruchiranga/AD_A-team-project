# %%
import re
import ast
import time
import requests
import pandas as pd
import numpy as np
import os.path
import urllib.request
import concurrent.futures
from os import listdir
from stem import Signal
from requests import get
from bs4 import BeautifulSoup
from datetime import datetime
from os.path import isfile, join
from stem.control import Controller

# %%
movie_subset = pd.read_pickle("./pickles/complete_178118.pkl")
movie_subset.head()
# Out:
#       tconst                              stars  oscarWins  nominations  wins  \
# 0  tt0014799  [nm0265550, nm0370407, nm0550195]          0            0     0
# 1  tt0014843  [nm0427659, nm0107574, nm0421138]          0            0     0
# 2  tt0014809  [nm0267916, nm0119572, nm0055809]          0            0     0
# 3  tt0014751             [nm0403710, nm0744408]          0            0     0
# 4  tt0014812  [nm0556953, nm0531962, nm0645941]          0            0     0
#
#   releaseDate releaseCountry plotKeywords budget worldwideGross metascore  \
# 0  1924-05-31             UK           []   None           None      None
# 1  1924-08-24            USA           []   None           None      None
# 2  1924-04-08            USA           []   None           None      None
# 3        None           None           []   None           None      None
# 4  1924-12-28            USA           []   None           None      None
#
#   musicProducer
# 0          None
# 1          None
# 2          None
# 3          None
# 4          None

# %%
stars_exploded = movie_subset.explode('stars')[['tconst', 'stars']]
stars_exploded.head()
# Out:
#       tconst      stars
# 0  tt0014799  nm0265550
# 0  tt0014799  nm0370407
# 0  tt0014799  nm0550195
# 1  tt0014843  nm0427659
# 1  tt0014843  nm0107574

# %%
stars_exploded.stars.nunique()
# Out:
# 138245

# %%
stars_counts = stars_exploded\
                    .groupby('stars')\
                    .count()\
                    .rename(columns={"tconst": "count"})\
                    .sort_values(['count'], ascending=False)
stars_counts.index.name = 'nconst'

# %%
stars_counts.tail(87400)
# Out:
#            count
# nconst
# nm0323379      2
# nm0098627      2
# nm0073596      2
# nm1054406      1
# nm1030940      1
# ...          ...
# nm0670816      1
# nm0163019      1
# nm0670779      1
# nm0670771      1
# nm9989884      1
#
# [87400 rows x 1 columns]

# %% [markdown]
# Close to 90000 stars have starred in only 1 movie in the chosen movie subset. For the purpose of bringing down the actors count for scraping,  for the moment, let's consider only the actors that have starred in more than 1 movie in the chosen movie subset.

# %%
print("Jessica Alba: {0} movies".format(stars_counts.loc['nm0004695']['count']))
print("Billy Boyd (Pippin from LOTR): {0} movies".format(stars_counts.loc['nm0101710']['count']))
print("Will Smith: {0} movies".format(stars_counts.loc['nm0000226']['count']))
print("Morgan Freeman: {0} movies".format(stars_counts.loc['nm0000151']['count']))
# Out:
# Jessica Alba: 4 movies
# Billy Boyd (Pippin from LOTR): 1 movies
# Will Smith: 12 movies
# Morgan Freeman: 26 movies

# %%
stars_subset = stars_counts[stars_counts['count'] > 1]
len(stars_subset)
# Out:
# 50848

# %% [markdown]
# ### Scraping

# %%
def get_tor_session():
    session = requests.session()
    # Tor uses the 9050 port as the default socks port
    session.proxies = {'http':  'socks5://127.0.0.1:9050',
                       'https': 'socks5://127.0.0.1:9050'}
    return session

def renew_connection():
    with Controller.from_port(port = 9051) as controller:
        controller.authenticate(password="password")
        controller.signal(Signal.NEWNYM)

def get_data(session, url):
    nconst=url.rsplit('/', 2)[-2]
    result = []
    
    
    with session.get(url) as req:
        req.raise_for_status()    
    
        body=req.text

        soup=BeautifulSoup(body,'html.parser')
        awards=soup.find_all('tr')
        if awards is not None:
            year_buf = []
            w_n_buf = []
            category_buf = []
            for award in awards:
                award_record = {
                    'nconst': nconst,
                    'year': None,
                    'category': None,
                    'w_n': None,
                    'description': None,
                    'movie': None,
                    'tconst': None
                } 
                if award.find('td', class_='award_year') is not None:
                    award_year_td = award.find('td', class_='award_year')
                    if award_year_td.find('a') is not None:
                        
                        year = award.find('td', class_='award_year').find('a').text
                        if year is not None:
                            try:
                                year = int(year.replace("\n", "").strip())
                                award_record['year'] = year
                                
                                # If the td has a row span more than 1, cache the value so it will be used 
                                # with the subsequent corresponding trs as well
                                if award_year_td['rowspan'] is not None:
                                    award_year_td_rs = int(award_year_td['rowspan'])
                                    for i in range(0, award_year_td_rs - 1):
                                        year_buf.append(year)
                            except:
                                print("Failed to parse int year {0}".format(year))

                elif len(year_buf) > 0:
                    buffed_year = year_buf.pop()
                    award_record['year'] = buffed_year

                if award.find('td',class_='award_outcome') is not None:
                    award_outcome_td = award.find('td',class_='award_outcome')
                    if award_outcome_td.find('span',class_='award_category') is not None:
                        award_cat = award_outcome_td.find('span',class_='award_category').text
                        award_record['category'] = award_cat
                        
                    if award_outcome_td.find('b') is not None:
                        w_n_txt = award_outcome_td.find('b').text
                        if w_n_txt is not None:
                            w_n = w_n_txt.replace("\n", "").strip()
                            award_record['w_n'] = w_n
                            
                    if award_outcome_td['rowspan'] is not None:
                        award_outcome_td_rs = int(award_outcome_td['rowspan'])
                        for i in range(0, award_outcome_td_rs - 1):
                            category_buf.append(award_cat)
                            w_n_buf.append(w_n)
                else:
                    if len(w_n_buf) > 0:
                        buffed_w_n = w_n_buf.pop()
                        award_record['w_n'] = buffed_w_n
                    if len(category_buf) > 0:
                        buffed_category = category_buf.pop()
                        award_record['category'] = buffed_category
                    

                if award.find('td', class_='award_description') is not None:
                    award_txt = award.find('td',class_='award_description').find(text=True, recursive=False)
                    award_info = award.find('td',class_='award_description').find('a', href=re.compile(r'.*tt\d{7}.*'))
                    if award_txt is not None:
                        award_record['description'] = award_txt.replace("\n", "").strip()

                    if award_info is not None:
                        tconst_res = re.search('tt\d{7}', award_info.get('href'))
                        if tconst_res is not None:
                            award_record['tconst'] = tconst_res.group(0)
                            award_record['movie'] = award_info.text
                result.append(award_record)

            return result

# %%
# Set the start index and end index. Ip is renewed after each chunk of urls of 'step_size'. 
# After every chunk, result is written to a pickle. So if you need to stop the execution in the middle, note the
# index range of the last successfully written pickle file (from the printed logs) and use the remaining range
# for start and end index to resume from where you stopped.
postfix = 'actors_subset'
s_idx = 0
e_idx = len(stars_subset)
# e_idx = 2000
step_size = 2000
pickles_save_dir = './pickles/{0}'.format(postfix)

base_url = 'https://www.imdb.com/name/{0}/awards'
urls=[]
for nconst in stars_subset.index[s_idx:e_idx]:
    urls.append(base_url.format(nconst))

used_ips = []
failed_urls = []


session = get_tor_session()
chunk_indeces = np.arange(0, len(urls), step_size)

for idx, start in enumerate(chunk_indeces, start=1):
    with concurrent.futures.ThreadPoolExecutor(max_workers=20) as executor:
        start_t = time.time()
        finals = []
        renew_connection()

        session = get_tor_session()
        new_ip = ast.literal_eval(session.get("http://httpbin.org/ip").text)["origin"].split(",")[0]
        while new_ip in used_ips:
            print("Renewed IP {0} already used. Waiting 5s to renew...".format(new_ip))
            time.sleep(5)
            renew_connection()
            session = get_tor_session()
            new_ip = ast.literal_eval(session.get("http://httpbin.org/ip").text)["origin"].split(",")[0]
        used_ips.append(new_ip)

        url_chunk = urls[start:start + step_size] + failed_urls
        failed_urls = []

        future_to_url = {executor.submit(get_data, session, url): url for url in url_chunk}
        for future in concurrent.futures.as_completed(future_to_url):
            url = future_to_url[future]
            try:
                data = future.result()
                finals += data
            except Exception as exc:
                failed_urls.append(url.strip("'"))
                print('%s generated an exception: %s. Added to retry list.' % (url, exc))

        concurrent.futures.wait(
            list(future_to_url.keys()), 
            timeout=None, 
            return_when=concurrent.futures.ALL_COMPLETED)
        end_t = time.time()
        print("chunk {0} of {1} completed with IP {2}. Took {3} seconds."\
              .format(idx, len(chunk_indeces), new_ip, end_t - start_t))   
        actors_df = pd.DataFrame(data=finals)
        if not os.path.exists(pickles_save_dir):
            os.makedirs(pickles_save_dir)
        pickle_path = "{4}/{0}_{1}-{2}_{3}.pkl"\
                        .format(idx, start, start + step_size, postfix, pickles_save_dir)
        actors_df.to_pickle(pickle_path)
        print("Wrote pickle {0} with {1} rows".format(pickle_path, len(actors_df)))

if len(failed_urls) > 0:
    print('\n\n\n\n!!!**********************************!!!')
    print('Failed to retrieve the following URLs.\n')
    print(failed_urls)
    print('\n!!!**********************************!!!')
    print('Note: Run the following cell to retry the failed urls')
else:
    print("\n\n\n\n!!!**********************************!!!\n")
    print("Scraping succeeded!")
    print('\n!!!**********************************!!!')
    print('''Note: Next, run the script that combine all pickles''')
# Out:
# chunk 1 of 26 completed with IP 185.220.101.57. Took 144.4004831314087 seconds.
# Wrote pickle ./pickles/actors_subset/1_0-2000_actors_subset.pkl with 18075 rows
# chunk 2 of 26 completed with IP 212.21.66.6. Took 148.19668579101562 seconds.
# Wrote pickle ./pickles/actors_subset/2_2000-4000_actors_subset.pkl with 16817 rows
# chunk 3 of 26 completed with IP 192.42.116.18. Took 222.7056758403778 seconds.
# Wrote pickle ./pickles/actors_subset/3_4000-6000_actors_subset.pkl with 12199 rows
# chunk 4 of 26 completed with IP 212.47.226.52. Took 119.3439691066742 seconds.
# Wrote pickle ./pickles/actors_subset/4_6000-8000_actors_subset.pkl with 11179 rows
# https://www.imdb.com/name/nm0354913/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0354913/awards. Added to retry list.
# https://www.imdb.com/name/nm0468130/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0468130/awards. Added to retry list.
# https://www.imdb.com/name/nm0901689/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0901689/awards. Added to retry list.
# https://www.imdb.com/name/nm0468435/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0468435/awards. Added to retry list.
# https://www.imdb.com/name/nm0439354/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0439354/awards. Added to retry list.
# https://www.imdb.com/name/nm0674878/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0674878/awards. Added to retry list.
# https://www.imdb.com/name/nm0598406/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0598406/awards. Added to retry list.
# https://www.imdb.com/name/nm0589711/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0589711/awards. Added to retry list.
# https://www.imdb.com/name/nm0299674/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0299674/awards. Added to retry list.
# https://www.imdb.com/name/nm0169051/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0169051/awards. Added to retry list.
# https://www.imdb.com/name/nm0625361/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0625361/awards. Added to retry list.
# https://www.imdb.com/name/nm0625986/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0625986/awards. Added to retry list.
# https://www.imdb.com/name/nm0405633/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0405633/awards. Added to retry list.
# https://www.imdb.com/name/nm0074059/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0074059/awards. Added to retry list.
# https://www.imdb.com/name/nm0439886/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0439886/awards. Added to retry list.
# https://www.imdb.com/name/nm0648975/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0648975/awards. Added to retry list.
# https://www.imdb.com/name/nm0406975/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0406975/awards. Added to retry list.
# https://www.imdb.com/name/nm0057754/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0057754/awards. Added to retry list.
# https://www.imdb.com/name/nm0208296/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0208296/awards. Added to retry list.
# https://www.imdb.com/name/nm0284544/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0284544/awards. Added to retry list.
# https://www.imdb.com/name/nm0616143/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0616143/awards. Added to retry list.
# https://www.imdb.com/name/nm0312768/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0312768/awards. Added to retry list.
# https://www.imdb.com/name/nm0423080/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0423080/awards. Added to retry list.
# https://www.imdb.com/name/nm0422600/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0422600/awards. Added to retry list.
# https://www.imdb.com/name/nm0286097/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0286097/awards. Added to retry list.
# https://www.imdb.com/name/nm0616343/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0616343/awards. Added to retry list.
# https://www.imdb.com/name/nm0056947/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0056947/awards. Added to retry list.
# https://www.imdb.com/name/nm0082639/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0082639/awards. Added to retry list.
# https://www.imdb.com/name/nm0418877/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0418877/awards. Added to retry list.
# https://www.imdb.com/name/nm0201239/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0201239/awards. Added to retry list.
# https://www.imdb.com/name/nm0064611/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0064611/awards. Added to retry list.
# https://www.imdb.com/name/nm0441587/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0441587/awards. Added to retry list.
# https://www.imdb.com/name/nm0302102/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0302102/awards. Added to retry list.
# https://www.imdb.com/name/nm0022338/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0022338/awards. Added to retry list.
# https://www.imdb.com/name/nm0619188/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0619188/awards. Added to retry list.
# https://www.imdb.com/name/nm0585506/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0585506/awards. Added to retry list.
# https://www.imdb.com/name/nm0904176/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0904176/awards. Added to retry list.
# https://www.imdb.com/name/nm0159346/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0159346/awards. Added to retry list.
# https://www.imdb.com/name/nm0442886/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0442886/awards. Added to retry list.
# https://www.imdb.com/name/nm0057063/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0057063/awards. Added to retry list.
# https://www.imdb.com/name/nm0075245/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0075245/awards. Added to retry list.
# https://www.imdb.com/name/nm0443229/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0443229/awards. Added to retry list.
# https://www.imdb.com/name/nm0679410/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0679410/awards. Added to retry list.
# https://www.imdb.com/name/nm0619057/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0619057/awards. Added to retry list.
# https://www.imdb.com/name/nm0275928/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0275928/awards. Added to retry list.
# https://www.imdb.com/name/nm0904962/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0904962/awards. Added to retry list.
# https://www.imdb.com/name/nm0653941/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0653941/awards. Added to retry list.
# https://www.imdb.com/name/nm0619053/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0619053/awards. Added to retry list.
# https://www.imdb.com/name/nm0586129/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0586129/awards. Added to retry list.
# https://www.imdb.com/name/nm0470514/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0470514/awards. Added to retry list.
# https://www.imdb.com/name/nm0419912/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0419912/awards. Added to retry list.
# https://www.imdb.com/name/nm0013696/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0013696/awards. Added to retry list.
# https://www.imdb.com/name/nm0191322/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0191322/awards. Added to retry list.
# https://www.imdb.com/name/nm0160666/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0160666/awards. Added to retry list.
# https://www.imdb.com/name/nm0468708/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0468708/awards. Added to retry list.
# https://www.imdb.com/name/nm0417762/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0417762/awards. Added to retry list.
# https://www.imdb.com/name/nm0190384/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0190384/awards. Added to retry list.
# https://www.imdb.com/name/nm0939223/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0939223/awards. Added to retry list.
# https://www.imdb.com/name/nm0160846/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0160846/awards. Added to retry list.
# https://www.imdb.com/name/nm0903055/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0903055/awards. Added to retry list.
# https://www.imdb.com/name/nm1352422/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm1352422/awards. Added to retry list.
# https://www.imdb.com/name/nm0621879/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0621879/awards. Added to retry list.
# https://www.imdb.com/name/nm0902607/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0902607/awards. Added to retry list.
# https://www.imdb.com/name/nm0656768/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0656768/awards. Added to retry list.
# https://www.imdb.com/name/nm0302802/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0302802/awards. Added to retry list.
# https://www.imdb.com/name/nm0622878/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0622878/awards. Added to retry list.
# https://www.imdb.com/name/nm0902188/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0902188/awards. Added to retry list.
# https://www.imdb.com/name/nm0468957/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0468957/awards. Added to retry list.
# https://www.imdb.com/name/nm0421155/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0421155/awards. Added to retry list.
# https://www.imdb.com/name/nm0019455/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0019455/awards. Added to retry list.
# https://www.imdb.com/name/nm0013028/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0013028/awards. Added to retry list.
# https://www.imdb.com/name/nm1785112/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm1785112/awards. Added to retry list.
# https://www.imdb.com/name/nm1798345/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm1798345/awards. Added to retry list.
# https://www.imdb.com/name/nm0065717/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0065717/awards. Added to retry list.
# https://www.imdb.com/name/nm0587711/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0587711/awards. Added to retry list.
# https://www.imdb.com/name/nm0866262/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0866262/awards. Added to retry list.
# https://www.imdb.com/name/nm0444528/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0444528/awards. Added to retry list.
# https://www.imdb.com/name/nm0404173/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0404173/awards. Added to retry list.
# https://www.imdb.com/name/nm0302285/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0302285/awards. Added to retry list.
# https://www.imdb.com/name/nm0013934/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0013934/awards. Added to retry list.
# https://www.imdb.com/name/nm0160517/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0160517/awards. Added to retry list.
# https://www.imdb.com/name/nm0082201/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0082201/awards. Added to retry list.
# https://www.imdb.com/name/nm0460578/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0460578/awards. Added to retry list.
# https://www.imdb.com/name/nm0421128/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0421128/awards. Added to retry list.
# https://www.imdb.com/name/nm0160532/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0160532/awards. Added to retry list.
# https://www.imdb.com/name/nm0883013/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0883013/awards. Added to retry list.
# https://www.imdb.com/name/nm1341861/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm1341861/awards. Added to retry list.
# https://www.imdb.com/name/nm0444753/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0444753/awards. Added to retry list.
# https://www.imdb.com/name/nm0013158/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0013158/awards. Added to retry list.
# https://www.imdb.com/name/nm0063053/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0063053/awards. Added to retry list.
# https://www.imdb.com/name/nm0620548/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0620548/awards. Added to retry list.
# https://www.imdb.com/name/nm0907216/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0907216/awards. Added to retry list.
# https://www.imdb.com/name/nm0865411/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0865411/awards. Added to retry list.
# https://www.imdb.com/name/nm0064957/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0064957/awards. Added to retry list.
# https://www.imdb.com/name/nm0190827/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0190827/awards. Added to retry list.
# https://www.imdb.com/name/nm0865396/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0865396/awards. Added to retry list.
# https://www.imdb.com/name/nm0417923/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0417923/awards. Added to retry list.
# https://www.imdb.com/name/nm2186174/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm2186174/awards. Added to retry list.
# https://www.imdb.com/name/nm0589898/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0589898/awards. Added to retry list.
# https://www.imdb.com/name/nm1824193/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm1824193/awards. Added to retry list.
# https://www.imdb.com/name/nm1267810/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm1267810/awards. Added to retry list.
# https://www.imdb.com/name/nm0011389/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0011389/awards. Added to retry list.
# https://www.imdb.com/name/nm0197582/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0197582/awards. Added to retry list.
# chunk 5 of 26 completed with IP 195.176.3.24. Took 96.85945916175842 seconds.
# Wrote pickle ./pickles/actors_subset/5_8000-10000_actors_subset.pkl with 8339 rows
# Renewed IP 185.220.101.57 already used. Waiting 5s to renew...
# Renewed IP 185.220.101.57 already used. Waiting 5s to renew...
# chunk 6 of 26 completed with IP 185.220.101.68. Took 151.9878408908844 seconds.
# Wrote pickle ./pickles/actors_subset/6_10000-12000_actors_subset.pkl with 7474 rows
# https://www.imdb.com/name/nm0181558/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0181558/awards. Added to retry list.
# https://www.imdb.com/name/nm0067070/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0067070/awards. Added to retry list.
# https://www.imdb.com/name/nm0061661/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0061661/awards. Added to retry list.
# https://www.imdb.com/name/nm0241478/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0241478/awards. Added to retry list.
# https://www.imdb.com/name/nm0796827/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0796827/awards. Added to retry list.
# https://www.imdb.com/name/nm0108503/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0108503/awards. Added to retry list.
# https://www.imdb.com/name/nm0606887/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0606887/awards. Added to retry list.
# https://www.imdb.com/name/nm0606541/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0606541/awards. Added to retry list.
# https://www.imdb.com/name/nm0350764/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0350764/awards. Added to retry list.
# https://www.imdb.com/name/nm0246842/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0246842/awards. Added to retry list.
# https://www.imdb.com/name/nm0280751/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0280751/awards. Added to retry list.
# https://www.imdb.com/name/nm0640618/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0640618/awards. Added to retry list.
# https://www.imdb.com/name/nm1526551/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm1526551/awards. Added to retry list.
# https://www.imdb.com/name/nm0187876/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0187876/awards. Added to retry list.
# https://www.imdb.com/name/nm0237897/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0237897/awards. Added to retry list.
# https://www.imdb.com/name/nm0119860/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0119860/awards. Added to retry list.
# https://www.imdb.com/name/nm0798611/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0798611/awards. Added to retry list.
# https://www.imdb.com/name/nm0000445/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0000445/awards. Added to retry list.
# https://www.imdb.com/name/nm0798440/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0798440/awards. Added to retry list.
# https://www.imdb.com/name/nm0798309/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0798309/awards. Added to retry list.
# https://www.imdb.com/name/nm0504144/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0504144/awards. Added to retry list.
# https://www.imdb.com/name/nm0241922/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0241922/awards. Added to retry list.
# https://www.imdb.com/name/nm0280961/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0280961/awards. Added to retry list.
# https://www.imdb.com/name/nm0798812/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0798812/awards. Added to retry list.
# https://www.imdb.com/name/nm0289799/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0289799/awards. Added to retry list.
# https://www.imdb.com/name/nm0124583/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0124583/awards. Added to retry list.
# https://www.imdb.com/name/nm0188012/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0188012/awards. Added to retry list.
# https://www.imdb.com/name/nm0350759/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0350759/awards. Added to retry list.
# https://www.imdb.com/name/nm0527099/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0527099/awards. Added to retry list.
# https://www.imdb.com/name/nm0639613/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0639613/awards. Added to retry list.
# https://www.imdb.com/name/nm0770711/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0770711/awards. Added to retry list.
# https://www.imdb.com/name/nm1065461/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm1065461/awards. Added to retry list.
# https://www.imdb.com/name/nm0635361/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0635361/awards. Added to retry list.
# https://www.imdb.com/name/nm0607074/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0607074/awards. Added to retry list.
# https://www.imdb.com/name/nm0284015/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0284015/awards. Added to retry list.
# https://www.imdb.com/name/nm0795025/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0795025/awards. Added to retry list.
# https://www.imdb.com/name/nm0451699/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0451699/awards. Added to retry list.
# https://www.imdb.com/name/nm0283932/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0283932/awards. Added to retry list.
# https://www.imdb.com/name/nm0237985/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0237985/awards. Added to retry list.
# https://www.imdb.com/name/nm0628647/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0628647/awards. Added to retry list.
# https://www.imdb.com/name/nm0600270/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0600270/awards. Added to retry list.
# https://www.imdb.com/name/nm0201030/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0201030/awards. Added to retry list.
# https://www.imdb.com/name/nm0190263/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0190263/awards. Added to retry list.
# https://www.imdb.com/name/nm0285864/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0285864/awards. Added to retry list.
# https://www.imdb.com/name/nm0287074/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0287074/awards. Added to retry list.
# https://www.imdb.com/name/nm0130797/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0130797/awards. Added to retry list.
# https://www.imdb.com/name/nm0064588/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0064588/awards. Added to retry list.
# https://www.imdb.com/name/nm0063274/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0063274/awards. Added to retry list.
# https://www.imdb.com/name/nm0057422/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0057422/awards. Added to retry list.
# https://www.imdb.com/name/nm0035000/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0035000/awards. Added to retry list.
# https://www.imdb.com/name/nm0231988/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0231988/awards. Added to retry list.
# https://www.imdb.com/name/nm1009441/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm1009441/awards. Added to retry list.
# https://www.imdb.com/name/nm0300561/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0300561/awards. Added to retry list.
# https://www.imdb.com/name/nm0747329/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0747329/awards. Added to retry list.
# https://www.imdb.com/name/nm0035018/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0035018/awards. Added to retry list.
# https://www.imdb.com/name/nm0882096/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0882096/awards. Added to retry list.
# https://www.imdb.com/name/nm0018664/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0018664/awards. Added to retry list.
# https://www.imdb.com/name/nm0600057/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0600057/awards. Added to retry list.
# https://www.imdb.com/name/nm0652677/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0652677/awards. Added to retry list.
# https://www.imdb.com/name/nm0782620/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0782620/awards. Added to retry list.
# https://www.imdb.com/name/nm0420022/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0420022/awards. Added to retry list.
# https://www.imdb.com/name/nm0348199/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0348199/awards. Added to retry list.
# https://www.imdb.com/name/nm1007729/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm1007729/awards. Added to retry list.
# https://www.imdb.com/name/nm0346581/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0346581/awards. Added to retry list.
# https://www.imdb.com/name/nm1090743/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm1090743/awards. Added to retry list.
# https://www.imdb.com/name/nm0810051/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0810051/awards. Added to retry list.
# https://www.imdb.com/name/nm0130979/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0130979/awards. Added to retry list.
# https://www.imdb.com/name/nm0352050/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0352050/awards. Added to retry list.
# https://www.imdb.com/name/nm0923554/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0923554/awards. Added to retry list.
# https://www.imdb.com/name/nm0883006/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0883006/awards. Added to retry list.
# https://www.imdb.com/name/nm0060694/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0060694/awards. Added to retry list.
# https://www.imdb.com/name/nm0903901/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0903901/awards. Added to retry list.
# https://www.imdb.com/name/nm0239155/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0239155/awards. Added to retry list.
# https://www.imdb.com/name/nm0883697/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0883697/awards. Added to retry list.
# https://www.imdb.com/name/nm0074065/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0074065/awards. Added to retry list.
# https://www.imdb.com/name/nm1686962/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm1686962/awards. Added to retry list.
# https://www.imdb.com/name/nm0906735/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0906735/awards. Added to retry list.
# https://www.imdb.com/name/nm0060693/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0060693/awards. Added to retry list.
# https://www.imdb.com/name/nm0601196/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0601196/awards. Added to retry list.
# https://www.imdb.com/name/nm0444201/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0444201/awards. Added to retry list.
# https://www.imdb.com/name/nm0620417/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0620417/awards. Added to retry list.
# https://www.imdb.com/name/nm0807238/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0807238/awards. Added to retry list.
# https://www.imdb.com/name/nm0514034/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0514034/awards. Added to retry list.
# https://www.imdb.com/name/nm0508536/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0508536/awards. Added to retry list.
# https://www.imdb.com/name/nm0448894/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0448894/awards. Added to retry list.
# https://www.imdb.com/name/nm0287471/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0287471/awards. Added to retry list.
# https://www.imdb.com/name/nm0649563/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0649563/awards. Added to retry list.
# https://www.imdb.com/name/nm0068755/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0068755/awards. Added to retry list.
# https://www.imdb.com/name/nm0252603/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0252603/awards. Added to retry list.
# https://www.imdb.com/name/nm0781958/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0781958/awards. Added to retry list.
# https://www.imdb.com/name/nm0276578/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0276578/awards. Added to retry list.
# https://www.imdb.com/name/nm0421716/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0421716/awards. Added to retry list.
# https://www.imdb.com/name/nm0809031/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0809031/awards. Added to retry list.
# https://www.imdb.com/name/nm0441574/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0441574/awards. Added to retry list.
# https://www.imdb.com/name/nm0509263/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0509263/awards. Added to retry list.
# https://www.imdb.com/name/nm0630453/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0630453/awards. Added to retry list.
# https://www.imdb.com/name/nm0612568/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0612568/awards. Added to retry list.
# https://www.imdb.com/name/nm0232194/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0232194/awards. Added to retry list.
# https://www.imdb.com/name/nm0782225/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0782225/awards. Added to retry list.
# https://www.imdb.com/name/nm1011131/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm1011131/awards. Added to retry list.
# https://www.imdb.com/name/nm0782220/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0782220/awards. Added to retry list.
# https://www.imdb.com/name/nm0537551/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0537551/awards. Added to retry list.
# https://www.imdb.com/name/nm0620291/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0620291/awards. Added to retry list.
# https://www.imdb.com/name/nm0748620/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0748620/awards. Added to retry list.
# https://www.imdb.com/name/nm0600608/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0600608/awards. Added to retry list.
# https://www.imdb.com/name/nm0807979/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0807979/awards. Added to retry list.
# https://www.imdb.com/name/nm0352731/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0352731/awards. Added to retry list.
# https://www.imdb.com/name/nm0903939/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0903939/awards. Added to retry list.
# https://www.imdb.com/name/nm0300353/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0300353/awards. Added to retry list.
# https://www.imdb.com/name/nm0457556/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0457556/awards. Added to retry list.
# https://www.imdb.com/name/nm0457557/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0457557/awards. Added to retry list.
# https://www.imdb.com/name/nm0620325/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0620325/awards. Added to retry list.
# https://www.imdb.com/name/nm1329827/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm1329827/awards. Added to retry list.
# https://www.imdb.com/name/nm0613147/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0613147/awards. Added to retry list.
# https://www.imdb.com/name/nm0906291/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0906291/awards. Added to retry list.
# https://www.imdb.com/name/nm0925750/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0925750/awards. Added to retry list.
# https://www.imdb.com/name/nm0275941/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0275941/awards. Added to retry list.
# https://www.imdb.com/name/nm0131469/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0131469/awards. Added to retry list.
# https://www.imdb.com/name/nm0618995/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0618995/awards. Added to retry list.
# https://www.imdb.com/name/nm0599562/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0599562/awards. Added to retry list.
# https://www.imdb.com/name/nm0000624/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0000624/awards. Added to retry list.
# https://www.imdb.com/name/nm0286596/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0286596/awards. Added to retry list.
# https://www.imdb.com/name/nm0811881/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0811881/awards. Added to retry list.
# https://www.imdb.com/name/nm0131387/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0131387/awards. Added to retry list.
# https://www.imdb.com/name/nm0897201/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0897201/awards. Added to retry list.
# https://www.imdb.com/name/nm1090404/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm1090404/awards. Added to retry list.
# https://www.imdb.com/name/nm0345708/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0345708/awards. Added to retry list.
# https://www.imdb.com/name/nm0783041/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0783041/awards. Added to retry list.
# https://www.imdb.com/name/nm0172006/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0172006/awards. Added to retry list.
# https://www.imdb.com/name/nm0016688/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0016688/awards. Added to retry list.
# chunk 7 of 26 completed with IP 83.97.20.184. Took 91.02737307548523 seconds.
# Wrote pickle ./pickles/actors_subset/7_12000-14000_actors_subset.pkl with 4706 rows
# https://www.imdb.com/name/nm0668734/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0668734/awards. Added to retry list.
# https://www.imdb.com/name/nm0272194/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0272194/awards. Added to retry list.
# https://www.imdb.com/name/nm1974002/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm1974002/awards. Added to retry list.
# https://www.imdb.com/name/nm0645516/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0645516/awards. Added to retry list.
# https://www.imdb.com/name/nm0614026/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0614026/awards. Added to retry list.
# https://www.imdb.com/name/nm0628002/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0628002/awards. Added to retry list.
# https://www.imdb.com/name/nm0067262/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0067262/awards. Added to retry list.
# https://www.imdb.com/name/nm0067367/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0067367/awards. Added to retry list.
# https://www.imdb.com/name/nm0067417/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0067417/awards. Added to retry list.
# https://www.imdb.com/name/nm0613598/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0613598/awards. Added to retry list.
# https://www.imdb.com/name/nm0019627/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0019627/awards. Added to retry list.
# https://www.imdb.com/name/nm0628708/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0628708/awards. Added to retry list.
# https://www.imdb.com/name/nm0900446/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0900446/awards. Added to retry list.
# https://www.imdb.com/name/nm0900245/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0900245/awards. Added to retry list.
# https://www.imdb.com/name/nm0626090/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0626090/awards. Added to retry list.
# https://www.imdb.com/name/nm0438792/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0438792/awards. Added to retry list.
# https://www.imdb.com/name/nm0195017/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0195017/awards. Added to retry list.
# https://www.imdb.com/name/nm0438805/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0438805/awards. Added to retry list.
# https://www.imdb.com/name/nm0187711/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0187711/awards. Added to retry list.
# https://www.imdb.com/name/nm1385848/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm1385848/awards. Added to retry list.
# https://www.imdb.com/name/nm0898653/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0898653/awards. Added to retry list.
# https://www.imdb.com/name/nm0448047/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0448047/awards. Added to retry list.
# https://www.imdb.com/name/nm0067588/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0067588/awards. Added to retry list.
# https://www.imdb.com/name/nm0195291/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0195291/awards. Added to retry list.
# https://www.imdb.com/name/nm0910607/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0910607/awards. Added to retry list.
# https://www.imdb.com/name/nm0612367/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0612367/awards. Added to retry list.
# https://www.imdb.com/name/nm0630674/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0630674/awards. Added to retry list.
# https://www.imdb.com/name/nm0196089/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0196089/awards. Added to retry list.
# ...
# https://www.imdb.com/name/nm0009943/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0009943/awards. Added to retry list.
# https://www.imdb.com/name/nm0270248/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0270248/awards. Added to retry list.
# https://www.imdb.com/name/nm0155588/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0155588/awards. Added to retry list.
# https://www.imdb.com/name/nm0215956/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0215956/awards. Added to retry list.
# https://www.imdb.com/name/nm0014408/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0014408/awards. Added to retry list.
# https://www.imdb.com/name/nm0216227/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0216227/awards. Added to retry list.
# https://www.imdb.com/name/nm0320909/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0320909/awards. Added to retry list.
# https://www.imdb.com/name/nm0072364/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0072364/awards. Added to retry list.
# https://www.imdb.com/name/nm0320889/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0320889/awards. Added to retry list.
# https://www.imdb.com/name/nm0138275/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0138275/awards. Added to retry list.
# https://www.imdb.com/name/nm0156033/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0156033/awards. Added to retry list.
# https://www.imdb.com/name/nm0028749/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0028749/awards. Added to retry list.
# https://www.imdb.com/name/nm0043273/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0043273/awards. Added to retry list.
# https://www.imdb.com/name/nm0003167/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0003167/awards. Added to retry list.
# https://www.imdb.com/name/nm0104136/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0104136/awards. Added to retry list.
# https://www.imdb.com/name/nm0216322/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0216322/awards. Added to retry list.
# https://www.imdb.com/name/nm0072329/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0072329/awards. Added to retry list.
# https://www.imdb.com/name/nm0072159/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0072159/awards. Added to retry list.
# https://www.imdb.com/name/nm0138081/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0138081/awards. Added to retry list.
# https://www.imdb.com/name/nm0216470/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0216470/awards. Added to retry list.
# https://www.imdb.com/name/nm0248187/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0248187/awards. Added to retry list.
# https://www.imdb.com/name/nm0014419/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0014419/awards. Added to retry list.
# https://www.imdb.com/name/nm0104380/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0104380/awards. Added to retry list.
# https://www.imdb.com/name/nm0320815/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0320815/awards. Added to retry list.
# https://www.imdb.com/name/nm0028837/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0028837/awards. Added to retry list.
# https://www.imdb.com/name/nm0072269/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0072269/awards. Added to retry list.
# https://www.imdb.com/name/nm0009750/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0009750/awards. Added to retry list.
# https://www.imdb.com/name/nm0248217/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0248217/awards. Added to retry list.
# https://www.imdb.com/name/nm0271446/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0271446/awards. Added to retry list.
# https://www.imdb.com/name/nm0186232/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0186232/awards. Added to retry list.
# https://www.imdb.com/name/nm0216152/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0216152/awards. Added to retry list.
# https://www.imdb.com/name/nm0321108/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0321108/awards. Added to retry list.
# https://www.imdb.com/name/nm0103854/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0103854/awards. Added to retry list.
# https://www.imdb.com/name/nm0043234/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0043234/awards. Added to retry list.
# https://www.imdb.com/name/nm0003155/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0003155/awards. Added to retry list.
# https://www.imdb.com/name/nm0248698/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0248698/awards. Added to retry list.
# https://www.imdb.com/name/nm0103877/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0103877/awards. Added to retry list.
# https://www.imdb.com/name/nm0156001/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0156001/awards. Added to retry list.
# https://www.imdb.com/name/nm0103822/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0103822/awards. Added to retry list.
# https://www.imdb.com/name/nm0037464/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0037464/awards. Added to retry list.
# https://www.imdb.com/name/nm0072694/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0072694/awards. Added to retry list.
# https://www.imdb.com/name/nm0103769/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0103769/awards. Added to retry list.
# https://www.imdb.com/name/nm0103802/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0103802/awards. Added to retry list.
# https://www.imdb.com/name/nm0270767/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0270767/awards. Added to retry list.
# https://www.imdb.com/name/nm0270945/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0270945/awards. Added to retry list.
# https://www.imdb.com/name/nm0072533/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0072533/awards. Added to retry list.
# https://www.imdb.com/name/nm0321159/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0321159/awards. Added to retry list.
# https://www.imdb.com/name/nm0271148/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0271148/awards. Added to retry list.
# https://www.imdb.com/name/nm0185795/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0185795/awards. Added to retry list.
# https://www.imdb.com/name/nm0186194/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0186194/awards. Added to retry list.
# https://www.imdb.com/name/nm0185690/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0185690/awards. Added to retry list.
# https://www.imdb.com/name/nm0271156/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0271156/awards. Added to retry list.
# https://www.imdb.com/name/nm0103976/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0103976/awards. Added to retry list.
# https://www.imdb.com/name/nm0072550/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0072550/awards. Added to retry list.
# https://www.imdb.com/name/nm0072556/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0072556/awards. Added to retry list.
# https://www.imdb.com/name/nm0216069/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0216069/awards. Added to retry list.
# https://www.imdb.com/name/nm0185835/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0185835/awards. Added to retry list.
# https://www.imdb.com/name/nm0321287/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0321287/awards. Added to retry list.
# https://www.imdb.com/name/nm0321358/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0321358/awards. Added to retry list.
# https://www.imdb.com/name/nm0321366/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0321366/awards. Added to retry list.
# https://www.imdb.com/name/nm0103980/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0103980/awards. Added to retry list.
# https://www.imdb.com/name/nm0321400/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0321400/awards. Added to retry list.
# https://www.imdb.com/name/nm0321388/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0321388/awards. Added to retry list.
# https://www.imdb.com/name/nm0248577/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0248577/awards. Added to retry list.
# https://www.imdb.com/name/nm0014551/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0014551/awards. Added to retry list.
# https://www.imdb.com/name/nm0318580/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0318580/awards. Added to retry list.
# https://www.imdb.com/name/nm0004571/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0004571/awards. Added to retry list.
# https://www.imdb.com/name/nm0020530/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0020530/awards. Added to retry list.
# https://www.imdb.com/name/nm0318569/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0318569/awards. Added to retry list.
# https://www.imdb.com/name/nm0044186/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0044186/awards. Added to retry list.
# https://www.imdb.com/name/nm0315826/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0315826/awards. Added to retry list.
# https://www.imdb.com/name/nm0135932/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0135932/awards. Added to retry list.
# https://www.imdb.com/name/nm0135876/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0135876/awards. Added to retry list.
# https://www.imdb.com/name/nm0029593/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0029593/awards. Added to retry list.
# https://www.imdb.com/name/nm0246195/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0246195/awards. Added to retry list.
# https://www.imdb.com/name/nm0068613/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0068613/awards. Added to retry list.
# https://www.imdb.com/name/nm0181963/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0181963/awards. Added to retry list.
# https://www.imdb.com/name/nm0044206/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0044206/awards. Added to retry list.
# https://www.imdb.com/name/nm0004450/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0004450/awards. Added to retry list.
# https://www.imdb.com/name/nm0315882/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0315882/awards. Added to retry list.
# https://www.imdb.com/name/nm0044140/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0044140/awards. Added to retry list.
# https://www.imdb.com/name/nm0219453/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0219453/awards. Added to retry list.
# https://www.imdb.com/name/nm0315942/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0315942/awards. Added to retry list.
# https://www.imdb.com/name/nm0219401/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0219401/awards. Added to retry list.
# https://www.imdb.com/name/nm0107573/awards generated an exception: 503 Server Error: Service Unavailable for url: https://www.imdb.com/name/nm0107573/awards. Added to retry list.
# chunk 24 of 26 completed with IP 171.25.193.25. Took 94.11798906326294 seconds.
# Wrote pickle ./pickles/actors_subset/24_46000-48000_actors_subset.pkl with 2542 rows
# Renewed IP 83.97.20.184 already used. Waiting 5s to renew...
# Renewed IP 83.97.20.184 already used. Waiting 5s to renew...
# chunk 25 of 26 completed with IP 185.220.101.69. Took 142.07862997055054 seconds.
# Wrote pickle ./pickles/actors_subset/25_48000-50000_actors_subset.pkl with 4940 rows
# chunk 26 of 26 completed with IP 23.129.64.206. Took 54.91601800918579 seconds.
# Wrote pickle ./pickles/actors_subset/26_50000-52000_actors_subset.pkl with 927 rows
#
#
#
#
# !!!**********************************!!!
#
# Scraping succeeded!
#
# !!!**********************************!!!
# Note: Next, run the script that combine all pickles

# %%
'''
Run the following script only if there were any failed URLS at the end of the previous script execution.
Run this several times if you still see failures until there are none. But if some dont succeed even 
after multiple attempts, its probably a problem on imdb side and we can just ignore them.
'''
# urls = failed_urls

# if len(urls) > 0:
#     retry_failed_urls = []

#     with concurrent.futures.ThreadPoolExecutor(max_workers=150) as executor:
#         session = get_tor_session(None)
#         chunk_indeces = np.arange(0, len(urls), step_size)

#         for idx, start in enumerate(chunk_indeces, start=1):
#             start_t = time.time()
#             finals = []
#             renew_connection()
#             session = get_tor_session(session)
#             new_ip = ast.literal_eval(session.get("http://httpbin.org/ip").text)["origin"].split(",")[0]
#             while new_ip in used_ips:
#                 print("Renewed IP {0} already used. Waiting 5s to renew...".format(new_ip))
#                 time.sleep(5)
#                 renew_connection()
#                 session = get_tor_session(session)
#                 new_ip = ast.literal_eval(session.get("http://httpbin.org/ip").text)["origin"].split(",")[0]
#             used_ips.append(new_ip)

#             url_chunk = urls[start:start + step_size] + retry_failed_urls
#             retry_failed_urls = []

#             future_to_url = {executor.submit(get_data, session, url): url for url in url_chunk}
#             for future in concurrent.futures.as_completed(future_to_url):
#                 url = future_to_url[future]
#                 try:
#                     data = future.result()
#                     finals.append(data)
#                 except Exception as exc:
#                     retry_failed_urls.append(url.strip("'"))
#                     print('%s generated an exception: %s. Added to retry list.' % (url, exc))

#             concurrent.futures.wait(list(future_to_url.keys()), timeout=None, return_when=concurrent.futures.ALL_COMPLETED)
#             end_t = time.time()
#             print("chunk {0} of {1} completed with IP {2}. Took {3} seconds.".format(idx, len(chunk_indeces), new_ip, end_t - start_t))   
#             actors_df = pd.DataFrame(data=finals)
#             if len(actors_df) > 0:
#                 pickle_path = "./pickles/actortor/{0}_{1}-{2}_{3}_retry.pkl".format(idx, start, start + step_size, postfix)
#                 actors_df.to_pickle(pickle_path)
#                 print("Wrote pickle {0} with {1} rows".format(pickle_path, len(actors_df)))

#         if len(retry_failed_urls) > 0:
#             print('\n\n\n\n!!!**********************************!!!')
#             print('Retry failed with the following URLs.\n')
#             print(retry_failed_urls)
#             print('\n!!!**********************************!!!')
#             print('Note: Run this script several times to see if all succeed.',
#             'If some dont, it probably means they wont ever. so just give them up.')
#         else:
#             print("\n\n\n\n!!!**********************************!!!\n")
#             print("Retry succeeded!")
#             print('\n!!!**********************************!!!')
#             print('''Note: Run the following script to combine all pickles''')

# %%
# Combine the created pickles into one Dataframe
# Ignore any sytem files starting with . or folders if any
pickles = [f for f in listdir(pickles_save_dir) if isfile(join(pickles_save_dir, f)) and not f.startswith('.')]

dfs = list(map(lambda x: pd.read_pickle("{0}/{1}".format(pickles_save_dir,x)), pickles))
combined_df = pd.concat(dfs)
combined_df.reset_index(drop=True, inplace=True)
if not os.path.exists('./pickles'):
    os.makedirs('./pickles')
combined_df.to_pickle("./pickles/complete_{1}_{0}.pkl".format(e_idx, postfix))
len(combined_df)
# Out:
# 139613

# %% [markdown]
# IMDB doesn't have awards information on many of the actors. So the number of actors in this final set is smaller than the original chosen subser

# %%
len(combined_df.nconst.unique())
# Out:
# 15567

# %%
actors_original = set(stars_counts.index)
actors_final = set(combined_df.groupby('nconst').count().index)

# %%
actors_original.difference(actors_final)
# Out:
# {'nm2748018',
#  'nm1155983',
#  'nm0241743',
#  'nm2507126',
#  'nm1269330',
#  'nm0222341',
#  'nm0224047',
#  'nm0308218',
#  'nm0469843',
#  'nm0829067',
#  'nm0634962',
#  'nm0642077',
#  'nm0005422',
#  'nm0867964',
#  'nm9208548',
#  'nm0616143',
#  'nm0066159',
#  'nm1128394',
#  'nm3770646',
#  'nm0904154',
#  'nm0374532',
#  'nm0684433',
#  'nm0315905',
#  'nm0336222',
#  'nm0233180',
#  'nm1207975',
#  'nm0160271',
#  'nm0174495',
#  'nm10100220',
#  'nm0875000',
#  'nm1282377',
#  'nm0582586',
#  'nm0694879',
#  'nm2275592',
#  'nm1239461',
#  'nm0244596',
#  'nm1002871',
#  'nm0149575',
#  'nm1416073',
#  'nm0049413',
#  'nm0686875',
#  'nm1717257',
#  'nm0463575',
#  'nm0724900',
#  'nm6478127',
#  'nm1914112',
#  'nm0010433',
#  'nm0193104',
#  'nm1696866',
#  'nm0900877',
#  'nm0001146',
#  'nm1298009',
#  'nm0645811',
#  'nm0147721',
#  'nm1090785',
#  'nm1616450',
#  'nm0880325',
#  'nm3153141',
#  'nm0153508',
#  'nm0952026',
#  'nm0755716',
#  'nm0240076',
#  'nm0232621',
#  'nm0328600',
#  'nm0896424',
#  'nm0917733',
#  'nm0380395',
#  'nm0241767',
#  'nm0381858',
#  'nm0698346',
#  'nm0754431',
#  'nm1172961',
#  'nm0378807',
#  'nm0242198',
#  'nm0160401',
#  'nm0044929',
#  'nm0747042',
#  'nm1275829',
#  'nm2509331',
#  'nm0462067',
#  'nm1066362',
#  'nm2021946',
#  'nm0170532',
#  'nm0419722',
#  'nm0323851',
#  'nm0096177',
#  'nm0707352',
#  'nm0703831',
#  'nm0452206',
#  'nm0029418',
#  'nm0041676',
#  'nm0039391',
#  'nm0632804',
#  'nm0592443',
#  'nm0241748',
#  'nm0360516',
#  'nm0922357',
#  'nm0150973',
#  'nm1098997',
#  'nm0303121',
#  'nm0378911',
#  'nm0165531',
#  'nm0610067',
#  'nm0305380',
#  'nm0094717',
#  'nm3245547',
#  'nm1706798',
#  'nm0580517',
#  'nm1091608',
#  'nm2067248',
#  'nm0880068',
#  'nm0556563',
#  'nm0551883',
#  'nm1597429',
#  'nm3473481',
#  'nm0244618',
#  'nm0357641',
#  'nm0409351',
#  'nm2310375',
#  'nm1792505',
#  'nm0477740',
#  'nm0018077',
#  'nm0039641',
#  'nm1155307',
#  'nm3710829',
#  'nm0100580',
#  'nm1957396',
#  'nm0662076',
#  'nm0956079',
#  'nm1142677',
#  'nm1301306',
#  'nm0055558',
#  'nm0198723',
#  'nm0637696',
#  'nm0177747',
#  'nm0026876',
#  'nm0501878',
#  'nm0617954',
#  'nm9871822',
#  'nm0319265',
#  'nm1096049',
#  'nm2173074',
#  'nm0920077',
#  'nm1175038',
#  'nm0729991',
#  'nm1833251',
#  'nm0521895',
#  'nm0190300',
#  'nm0005536',
#  'nm0654373',
#  'nm0053016',
#  'nm0262315',
#  'nm0654210',
#  'nm5623321',
#  'nm0078793',
#  'nm0450242',
#  'nm0672872',
#  'nm0014698',
#  'nm0372742',
#  'nm1024383',
#  'nm0632514',
#  'nm0727165',
#  'nm0436155',
#  'nm0200012',
#  'nm0638995',
#  'nm8590822',
#  'nm0233998',
#  'nm0586450',
#  'nm0556423',
#  'nm0880723',
#  'nm0083220',
#  'nm1449138',
#  'nm0093393',
#  'nm1218566',
#  'nm2061768',
#  'nm0166009',
#  'nm0188558',
#  'nm0297775',
#  'nm4388545',
#  'nm0197797',
#  'nm0053313',
#  'nm0694683',
#  'nm0536385',
#  'nm1731810',
#  'nm1819065',
#  'nm0856738',
#  'nm1111024',
#  'nm10172788',
#  'nm0590691',
#  'nm0644487',
#  'nm0099740',
#  'nm0676912',
#  'nm0328113',
#  'nm0599028',
#  'nm0299493',
#  'nm3611927',
#  'nm0784664',
#  'nm0686491',
#  'nm0221834',
#  'nm0133421',
#  'nm0401942',
#  'nm1211518',
#  'nm0599439',
#  'nm0122359',
#  'nm0702950',
#  'nm0952425',
#  'nm1161341',
#  'nm1921574',
#  'nm1136770',
#  'nm1723041',
#  'nm2507024',
#  'nm1135609',
#  'nm0296451',
#  'nm1190716',
#  'nm0447813',
#  'nm0580685',
#  'nm1687498',
#  'nm5404439',
#  'nm0319948',
#  'nm1028803',
#  'nm0534957',
#  'nm0315642',
#  'nm0329060',
#  'nm0592606',
#  'nm3298445',
#  'nm2523832',
#  'nm0051362',
#  'nm3849500',
#  'nm0575661',
#  'nm0070128',
#  'nm0702677',
#  'nm0350853',
#  'nm0271543',
#  'nm0061790',
#  'nm2096867',
#  'nm0423332',
#  'nm0218464',
#  'nm1205073',
#  'nm0298857',
#  'nm0584464',
#  'nm2742829',
#  'nm0508428',
#  'nm0289811',
#  'nm2201503',
#  'nm0581909',
#  'nm0507060',
#  'nm0775905',
#  'nm0129221',
#  'nm0860112',
#  'nm0394651',
#  'nm0388902',
#  'nm1333453',
#  'nm0914787',
#  'nm0149543',
#  'nm0737906',
#  'nm0725309',
#  'nm0882331',
#  'nm0971908',
#  'nm2237536',
#  'nm0741048',
#  'nm0519538',
#  'nm0416611',
#  'nm4517600',
#  'nm2661414',
#  'nm1197710',
#  'nm1116119',
#  'nm0767375',
#  'nm0949599',
#  'nm6861715',
#  'nm0097207',
#  'nm1260965',
#  'nm1018900',
#  'nm0851872',
#  'nm0033821',
#  'nm0777684',
#  'nm0740756',
#  'nm0255724',
#  'nm0118799',
#  'nm0790452',
#  'nm3989715',
#  'nm2256686',
#  'nm0080343',
#  'nm0525064',
#  'nm1099086',
#  'nm0153599',
#  'nm0872823',
#  'nm0266626',
#  'nm0657829',
#  'nm0135572',
#  'nm2799593',
#  'nm0383414',
#  'nm1248783',
#  'nm0887675',
#  'nm0436877',
#  'nm3547013',
#  'nm0528849',
#  'nm0136797',
#  'nm0527561',
#  'nm0070131',
#  'nm0557176',
#  'nm1515240',
#  'nm0009603',
#  'nm0350314',
#  'nm1304441',
#  'nm0056228',
#  'nm3709102',
#  'nm1249527',
#  'nm0369006',
#  'nm2284215',
#  'nm1290417',
#  'nm1095046',
#  'nm1300853',
#  'nm0622491',
#  'nm0251288',
#  'nm0207484',
#  'nm0277278',
#  'nm1254456',
#  'nm4053956',
#  'nm1689698',
#  'nm2900472',
#  'nm1172471',
#  'nm1000331',
#  'nm0770153',
#  'nm0918077',
#  'nm1180235',
#  'nm0476339',
#  'nm2925072',
#  'nm3003356',
#  'nm0998482',
#  'nm3737973',
#  'nm0078882',
#  'nm1001075',
#  'nm0065581',
#  'nm0409280',
#  'nm1719905',
#  'nm0002391',
#  'nm0249626',
#  'nm0998190',
#  'nm0517125',
#  'nm0821782',
#  'nm1188430',
#  'nm0105551',
#  'nm0394757',
#  'nm0234270',
#  'nm0547091',
#  'nm0398446',
#  'nm0536085',
#  'nm0690190',
#  'nm0777617',
#  'nm0109323',
#  'nm0232213',
#  'nm0383026',
#  'nm0091072',
#  'nm0855593',
#  'nm0353401',
#  'nm0380386',
#  'nm0424260',
#  'nm0202959',
#  'nm0306894',
#  'nm0933264',
#  'nm1560171',
#  'nm2195916',
#  'nm1285320',
#  'nm2378806',
#  'nm0605797',
#  'nm0592317',
#  'nm0618517',
#  'nm1102373',
#  'nm0709526',
#  'nm0736621',
#  'nm0956101',
#  'nm0270480',
#  'nm0135122',
#  'nm1128720',
#  'nm1122031',
#  'nm0532924',
#  'nm0550816',
#  'nm0356056',
#  'nm0364220',
#  'nm0667827',
#  'nm1675496',
#  'nm0148409',
#  'nm0591881',
#  'nm0305849',
#  'nm0786781',
#  'nm2159080',
#  'nm1233505',
#  'nm0135962',
#  'nm0501955',
#  'nm0026841',
#  'nm0692037',
#  'nm0092051',
#  'nm0807761',
#  'nm0388529',
#  'nm4888042',
#  'nm3144651',
#  'nm0135781',
#  'nm0771299',
#  'nm0467178',
#  'nm0813305',
#  'nm0837262',
#  'nm1403949',
#  'nm0502533',
#  'nm0467979',
#  'nm0667236',
#  'nm0210907',
#  'nm0147271',
#  'nm1049634',
#  'nm0431475',
#  'nm1025976',
#  'nm1067548',
#  'nm0229419',
#  'nm0852328',
#  'nm0647398',
#  'nm0452046',
#  'nm2464167',
#  'nm0760602',
#  'nm0390258',
#  'nm0128994',
#  'nm0369173',
#  'nm3492864',
#  'nm0793416',
#  'nm8571431',
#  'nm0267511',
#  'nm0546891',
#  'nm3453609',
#  'nm0250209',
#  'nm0731195',
#  'nm0051503',
#  'nm1171799',
#  'nm0708223',
#  'nm0359109',
#  'nm0165351',
#  'nm1302197',
#  'nm1165615',
#  'nm1559102',
#  'nm1553209',
#  'nm1131193',
#  'nm0336565',
#  'nm10798847',
#  'nm0137046',
#  'nm1084440',
#  'nm0034781',
#  'nm0957452',
#  'nm0328710',
#  'nm0902902',
#  'nm0096270',
#  'nm0837286',
#  'nm0758034',
#  'nm0853635',
#  'nm0763746',
#  'nm0088515',
#  'nm0597379',
#  'nm0675627',
#  'nm0538410',
#  'nm0837716',
#  'nm0599867',
#  'nm0040301',
#  'nm0675272',
#  'nm0311962',
#  'nm0600898',
#  'nm2264499',
#  'nm0843883',
#  'nm1996751',
#  'nm2578205',
#  'nm2651550',
#  'nm1407938',
#  'nm0001090',
#  'nm0160048',
#  'nm1070319',
#  'nm0334197',
#  'nm0648965',
#  'nm0520211',
#  'nm0571329',
#  'nm0583103',
#  'nm0554322',
#  'nm0912247',
#  'nm1389635',
#  'nm0444146',
#  'nm0944232',
#  'nm0690456',
#  'nm3074916',
#  'nm0225744',
#  'nm0888596',
#  'nm0354072',
#  'nm1064703',
#  'nm0906531',
#  'nm1018999',
#  'nm0115558',
#  'nm0147907',
#  'nm0687886',
#  'nm0480002',
#  'nm1237900',
#  'nm0316233',
#  'nm0058162',
#  'nm0318879',
#  'nm0087408',
#  'nm0628893',
#  'nm0400296',
#  'nm0681740',
#  'nm0009393',
#  'nm0941177',
#  'nm0034290',
#  'nm8212505',
#  'nm0273857',
#  'nm0777125',
#  'nm0582548',
#  'nm0183039',
#  'nm0765012',
#  'nm1091310',
#  'nm0060397',
#  'nm0021737',
#  'nm0053260',
#  'nm0916366',
#  'nm0415741',
#  'nm0122134',
#  'nm0143339',
#  'nm0398956',
#  'nm1125105',
#  'nm0508766',
#  'nm0876447',
#  'nm0993647',
#  'nm1507295',
#  'nm0017879',
#  'nm0955567',
#  'nm0947475',
#  'nm0214009',
#  'nm0252429',
#  'nm0091909',
#  'nm0139067',
#  'nm0050875',
#  'nm1266271',
#  'nm0804636',
#  'nm0005164',
#  'nm1427641',
#  'nm0002114',
#  'nm0003261',
#  'nm0508355',
#  'nm0604541',
#  'nm1185617',
#  'nm0510862',
#  'nm0502091',
#  'nm0059824',
#  'nm0172333',
#  'nm1251540',
#  'nm0218635',
#  'nm1156948',
#  'nm0375213',
#  'nm1180262',
#  'nm1091390',
#  'nm0435909',
#  'nm0567045',
#  'nm0246888',
#  'nm1232954',
#  'nm0933339',
#  'nm1036981',
#  'nm2099121',
#  'nm0538909',
#  'nm0102358',
#  'nm0600716',
#  'nm0441365',
#  'nm0056346',
#  'nm2491595',
#  'nm0367373',
#  'nm0114233',
#  'nm3921986',
#  'nm2400035',
#  'nm1052732',
#  'nm9772472',
#  'nm0004830',
#  'nm0043613',
#  'nm1794216',
#  'nm0311452',
#  'nm0410301',
#  'nm1127660',
#  'nm3929864',
#  'nm0178898',
#  'nm1065614',
#  'nm0539188',
#  'nm0642522',
#  'nm0236441',
#  'nm0830435',
#  'nm0036026',
#  'nm1068591',
#  'nm1421110',
#  'nm0215141',
#  'nm0153679',
#  'nm2621831',
#  'nm0097512',
#  'nm0394400',
#  'nm0143212',
#  'nm0927962',
#  'nm0463816',
#  'nm7308846',
#  'nm0173416',
#  'nm0443662',
#  'nm0996655',
#  'nm1078299',
#  'nm9508938',
#  'nm2641096',
#  'nm1158388',
#  'nm1025596',
#  'nm0812306',
#  'nm0833000',
#  'nm0874826',
#  'nm0425766',
#  'nm1695015',
#  'nm0172829',
#  'nm0087162',
#  'nm0212304',
#  'nm0373206',
#  'nm0665874',
#  'nm0597526',
#  'nm4115230',
#  'nm0025347',
#  'nm0015300',
#  'nm6662234',
#  'nm0227769',
#  'nm0229082',
#  'nm0710086',
#  'nm0685277',
#  'nm1705380',
#  'nm1088606',
#  'nm0407049',
#  'nm1671276',
#  'nm0090032',
#  'nm0010692',
#  'nm0032895',
#  'nm0560598',
#  'nm0128408',
#  'nm0858651',
#  'nm0240391',
#  'nm0133880',
#  'nm2345429',
#  'nm0286596',
#  'nm0515156',
#  'nm2147628',
#  'nm0449940',
#  'nm0303198',
#  'nm1280137',
#  'nm0391940',
#  'nm0495159',
#  'nm0903850',
#  'nm0567442',
#  'nm0943158',
#  'nm0585091',
#  'nm0457244',
#  'nm0243584',
#  'nm0031340',
#  'nm0103508',
#  'nm0082212',
#  'nm0225216',
#  'nm2154792',
#  'nm1142954',
#  'nm1257305',
#  'nm0166265',
#  'nm0432253',
#  'nm0813612',
#  'nm0407411',
#  'nm0101459',
#  'nm0163906',
#  'nm1002677',
#  'nm0784416',
#  'nm0852175',
#  'nm0331002',
#  'nm1349712',
#  'nm0605628',
#  'nm0039074',
#  'nm0414782',
#  'nm0741130',
#  'nm0064710',
#  'nm1064269',
#  'nm6024272',
#  'nm0284796',
#  'nm0422622',
#  'nm1101873',
#  'nm0408801',
#  'nm3812850',
#  'nm0888134',
#  'nm0271242',
#  'nm2703584',
#  'nm1010863',
#  'nm4163730',
#  'nm1673403',
#  'nm0210377',
#  'nm0828353',
#  'nm0223742',
#  'nm0188616',
#  'nm0620173',
#  'nm6090282',
#  'nm0958472',
#  'nm0719903',
#  'nm0249368',
#  'nm0751181',
#  'nm3067018',
#  'nm0819265',
#  'nm0657459',
#  'nm0499164',
#  'nm0125480',
#  'nm0854824',
#  'nm1326253',
#  'nm1106071',
#  'nm1002083',
#  'nm8618251',
#  'nm0436272',
#  'nm7502355',
#  'nm2742195',
#  'nm0074357',
#  'nm0534421',
#  'nm0880069',
#  'nm0028145',
#  'nm0351069',
#  'nm0935955',
#  'nm0375333',
#  'nm0069594',
#  'nm1115513',
#  'nm0217974',
#  'nm3597257',
#  'nm0229720',
#  'nm0916305',
#  'nm0943914',
#  'nm0432399',
#  'nm0702249',
#  'nm1108542',
#  'nm0882113',
#  'nm1208036',
#  'nm0203897',
#  'nm1143792',
#  'nm0398533',
#  'nm0598902',
#  'nm1267320',
#  'nm0148768',
#  'nm0093037',
#  'nm0001568',
#  'nm0571000',
#  'nm0139576',
#  'nm0710603',
#  'nm0856372',
#  'nm0544425',
#  'nm1109458',
#  'nm0793674',
#  'nm0654768',
#  'nm2592189',
#  'nm1632246',
#  'nm0205789',
#  'nm0255253',
#  'nm0898736',
#  'nm0703491',
#  'nm6164470',
#  'nm0849431',
#  'nm0151809',
#  'nm0041888',
#  'nm0957323',
#  'nm1181616',
#  'nm0845729',
#  'nm0071913',
#  'nm0620306',
#  'nm0919561',
#  'nm0881690',
#  'nm0127904',
#  'nm0912503',
#  'nm0491467',
#  'nm0893520',
#  'nm0476097',
#  'nm0419004',
#  'nm0902672',
#  'nm0997347',
#  'nm0218011',
#  'nm0274134',
#  'nm0096401',
#  'nm0852599',
#  'nm0438192',
#  'nm0303052',
#  'nm0722564',
#  'nm3537913',
#  'nm1128208',
#  'nm0733858',
#  'nm0283098',
#  'nm0296937',
#  'nm0854516',
#  'nm0321503',
#  'nm4978627',
#  'nm0183866',
#  'nm0492401',
#  'nm0864937',
#  'nm0150014',
#  'nm1181005',
#  'nm1390854',
#  'nm0250031',
#  'nm0923338',
#  'nm2762553',
#  'nm0282688',
#  'nm0673251',
#  'nm0998790',
#  'nm0552879',
#  'nm0557295',
#  'nm5048523',
#  'nm0347503',
#  'nm0754156',
#  'nm0692784',
#  'nm0160109',
#  'nm0673713',
#  'nm0068410',
#  'nm0451592',
#  'nm1033013',
#  'nm1796220',
#  'nm5358293',
#  'nm0463511',
#  'nm1042937',
#  'nm0714835',
#  'nm0806867',
#  'nm0797624',
#  'nm0945544',
#  'nm0457870',
#  'nm0228672',
#  'nm1038074',
#  'nm0678556',
#  'nm1892980',
#  'nm0878036',
#  'nm1125321',
#  'nm3012732',
#  'nm0147078',
#  'nm0617471',
#  'nm0948679',
#  'nm0010374',
#  'nm1191244',
#  'nm0533831',
#  'nm1307723',
#  'nm1040739',
#  'nm0606274',
#  'nm0011148',
#  'nm3481877',
#  'nm0390342',
#  'nm0827261',
#  'nm0019835',
#  'nm7530654',
#  'nm3939125',
#  'nm0756717',
#  'nm6082210',
#  'nm1882436',
#  'nm0863877',
#  'nm0560501',
#  'nm2558325',
#  'nm0390603',
#  'nm1240842',
#  'nm1138082',
#  'nm0788152',
#  'nm1005460',
#  'nm0227403',
#  'nm0295083',
#  'nm0264776',
#  'nm1732008',
#  'nm0172871',
#  'nm1350907',
#  'nm0353738',
#  'nm0059594',
#  'nm0135632',
#  'nm0843448',
#  'nm5405850',
#  'nm0112191',
#  'nm0340743',
#  'nm0776226',
#  'nm0450453',
#  'nm1098712',
#  'nm0032889',
#  'nm1259039',
#  'nm0771669',
#  'nm0299233',
#  'nm5177113',
#  'nm0206241',
#  'nm0016126',
#  'nm1267554',
#  'nm0309605',
#  'nm1109198',
#  'nm4396306',
#  'nm1162372',
#  'nm0207884',
#  'nm0148791',
#  'nm0158662',
#  'nm2637673',
#  'nm0887481',
#  'nm0113595',
#  'nm0149707',
#  'nm0762844',
#  'nm1524579',
#  'nm2682442',
#  'nm0493958',
#  'nm0518606',
#  'nm0820483',
#  'nm0539146',
#  'nm0075849',
#  'nm0385682',
#  'nm0931186',
#  'nm10620294',
#  'nm0099882',
#  'nm0992964',
#  'nm0465659',
#  'nm0951052',
#  'nm0774829',
#  'nm0014584',
#  'nm0991830',
#  'nm7549323',
#  'nm0504745',
#  'nm0532533',
#  'nm1078689',
#  'nm0585481',
#  'nm1254570',
#  'nm1142511',
#  'nm0578498',
#  'nm4856393',
#  'nm1978097',
#  'nm0944452',
#  'nm0257147',
#  'nm0617088',
#  'nm0603101',
#  'nm2233076',
#  'nm0913444',
#  'nm0621238',
#  'nm2036444',
#  'nm0266631',
#  'nm8915430',
#  'nm1118949',
#  'nm1062821',
#  'nm0051575',
#  'nm0111013',
#  'nm0115824',
#  'nm0366126',
#  'nm0695412',
#  'nm0852406',
#  'nm0376905',
#  'nm3370291',
#  'nm0481151',
#  'nm1428048',
#  'nm1094799',
#  'nm0624735',
#  'nm0535434',
#  'nm0343064',
#  'nm0387066',
#  'nm0426127',
#  'nm1017323',
#  'nm0197198',
#  'nm0148637',
#  'nm0127693',
#  'nm0150596',
#  'nm1107844',
#  'nm1128492',
#  'nm0063403',
#  'nm0953388',
#  'nm0110412',
#  'nm0058342',
#  'nm0115492',
#  'nm1817379',
#  'nm0679582',
#  'nm0045796',
#  'nm0970541',
#  'nm0824262',
#  'nm0485310',
#  'nm0835992',
#  'nm1516326',
#  'nm0782174',
#  'nm0094189',
#  'nm0270440',
#  'nm2529553',
#  'nm0457236',
#  'nm0938325',
#  'nm0029479',
#  'nm1412051',
#  'nm2046476',
#  'nm0362802',
#  'nm0759430',
#  'nm0185795',
#  'nm0495522',
#  'nm0246192',
#  'nm1931317',
#  'nm0112841',
#  'nm0161048',
#  'nm0149896',
#  'nm0086748',
#  'nm0442227',
#  'nm0292744',
#  'nm1194516',
#  'nm0694900',
#  'nm0402172',
#  'nm0709334',
#  'nm0667047',
#  'nm0960940',
#  'nm1165311',
#  'nm0529166',
#  'nm0225610',
#  'nm3442611',
#  'nm0475576',
#  'nm0586147',
#  'nm0004837',
#  'nm1832016',
#  'nm0385796',
#  'nm1486489',
#  'nm0484666',
#  'nm0837072',
#  'nm2448104',
#  'nm10591277',
#  ...}

# %% [markdown]
# Awards of one random actor

# %%
combined_df[combined_df.nconst == 'nm0003501']
# Out:
#            nconst  year                category      w_n  \
# 112000  nm0026364  2019             Image Award   Winner
# 112001  nm0026364  2018             Image Award   Winner
# 112002  nm0026364  2017             Image Award   Winner
# 112003  nm0026364  2017             Image Award  Nominee
# 112004  nm0026364  2016             Image Award   Winner
# 112005  nm0026364  2015             Image Award   Winner
# 112006  nm0026364  2013             Image Award  Nominee
# 112007  nm0026364  2011             Image Award  Nominee
# 112008  nm0026364  2010             Image Award  Nominee
# 112009  nm0026364  2009             Image Award  Nominee
# 112010  nm0026364  2008             Image Award  Nominee
# 112011  nm0026364  2006             Image Award  Nominee
# 112012  nm0026364  2003             Image Award  Nominee
# 112013  nm0026364  2002             Image Award  Nominee
# 112014  nm0026364  2016             Blimp Award  Nominee
# 112015  nm0026364  2006               NBR Award   Winner
# 112016  nm0026364  2019   OFTA Television Award  Nominee
# 112017  nm0026364  2018   OFTA Television Award  Nominee
# 112018  nm0026364  2017   OFTA Television Award  Nominee
# 112019  nm0026364  2016   OFTA Television Award  Nominee
# 112020  nm0026364  2015   OFTA Television Award  Nominee
# 112021  nm0026364  2017   People's Choice Award  Nominee
# 112022  nm0026364  2017               PGA Award  Nominee
# 112023  nm0026364  2004            Razzie Award  Nominee
# 112024  nm0026364  2019         Satellite Award  Nominee
# 112025  nm0026364  2016         Satellite Award  Nominee
# 112026  nm0026364  2006         Satellite Award   Winner
# 112027  nm0026364  2018                   Actor  Nominee
# 112028  nm0026364  2017                   Actor  Nominee
# 112029  nm0026364  2017                   Actor  Nominee
# 112030  nm0026364  2007                   Actor  Nominee
# 112031  nm0026364  2006                   Actor  Nominee
# 112032  nm0026364  2019       Teen Choice Award  Nominee
# 112033  nm0026364  2018       Teen Choice Award  Nominee
# 112034  nm0026364  2017       Teen Choice Award  Nominee
# 112035  nm0026364  2017       Teen Choice Award  Nominee
# 112036  nm0026364  2016       Teen Choice Award  Nominee
# 112037  nm0026364  2015       Teen Choice Award  Nominee
# 112038  nm0026364  2004       Teen Choice Award  Nominee
# 112039  nm0026364  2003       Teen Choice Award  Nominee
# 112040  nm0026364  2002             WAFCA Award   Winner
# 112041  nm0096493  1956          Primetime Emmy  Nominee
# 112042  nm1682953  2019          SIIMA - Telugu  Nominee
# 112043  nm0014133  2019   Canadian Screen Award  Nominee
# 112044  nm0014133  2007                   Jutra   Winner
# 112045  nm0014133  2003                   Jutra  Nominee
# 112046  nm0014133  2001                   Jutra   Winner
# 112047  nm0005007  2013   Canadian Screen Award  Nominee
# 112048  nm0005007  2007                  Gracie   Winner
# 112049  nm0005007  2002  Golden Satellite Award  Nominee
#
#                                               description  \
# 112000               Outstanding Actor in a Comedy Series
# 112001               Outstanding Actor in a Comedy Series
# 112002               Outstanding Actor in a Comedy Series
# 112003  Outstanding Host in a News, Talk, Reality, or ...
# 112004               Outstanding Actor in a Comedy Series
# 112005               Outstanding Actor in a Comedy Series
# 112006               Outstanding Actor in a Comedy Series
# 112007                Outstanding Actor in a Drama Series
# 112008                Outstanding Actor in a Drama Series
# 112009                Outstanding Actor in a Drama Series
# 112010                Outstanding Actor in a Drama Series
# 112011   Outstanding Supporting Actor in a Motion Picture
# 112012   Outstanding Supporting Actor in a Motion Picture
# 112013   Outstanding Supporting Actor in a Motion Picture
# 112014                           Favorite Family TV Actor
# 112015                         Best Acting by an Ensemble
# 112016                      Best Actor in a Comedy Series
# 112017                      Best Actor in a Comedy Series
# 112018                      Best Actor in a Comedy Series
# 112019                      Best Actor in a Comedy Series
# 112020                      Best Actor in a Comedy Series
# 112021                          Favorite Comedic TV Actor
# 112022  Outstanding Producer of Episodic Television, C...
# 112023                             Worst Supporting Actor
# 112024          Best Actor in a Series, Comedy or Musical
# 112025          Best Actor in a Series, Comedy or Musical
# 112026                      Best Ensemble, Motion Picture
# 112027  Outstanding Performance by a Male Actor in a C...
# 112028  Outstanding Performance by an Ensemble in a Co...
# 112029  Outstanding Performance by a Male Actor in a C...
# 112030  Outstanding Performance by a Cast in a Motion ...
# 112031  Outstanding Performance by a Cast in a Motion ...
# 112032                            Choice TV Actor: Comedy
# 112033                            Choice TV Actor: Comedy
# 112034                            Choice TV Actor: Comedy
# 112035                                  Choice: Hissy Fit
# 112036                            Choice TV Actor: Comedy
# 112037                            Choice TV Actor: Comedy
# 112038                           Choice TV Actor - Comedy
# 112039                        Choice Movie Actor - Comedy
# 112040                                      Best Ensemble
# 112041               Best Specialty Act - Single or Group
# 112042                              Best Supporting Actor
# 112043       Performance by an Actor in a Supporting Role
# 112044                       Best Actor (Meilleur Acteur)
# 112045                       Best Actor (Meilleur Acteur)
# 112046                       Best Actor (Meilleur Acteur)
# 112047  Best Performance by an Actress in a Leading Ro...
# 112048          Outstanding Female Lead in a Drama Series
# 112049  Best Performance by an Actress in a Supporting...
#
#                                             movie     tconst
# 112000                                  Black-ish  tt3487356
# 112001                                  Black-ish  tt3487356
# 112002                                  Black-ish  tt3487356
# 112003                            BET Awards 2016  tt5847012
# 112004                                  Black-ish  tt3487356
# 112005                                  Black-ish  tt3487356
# 112006                             Guys with Kids  tt2281583
# 112007                                Law & Order  tt0098844
# 112008                                Law & Order  tt0098844
# 112009                                Law & Order  tt0098844
# 112010                                    K-Ville  tt0952665
# 112011                              Hustle & Flow  tt0410097
# 112012                                 Barbershop  tt0303714
# 112013                     Two Can Play That Game  tt0269341
# 112014                                  Black-ish  tt3487356
# 112015                               The Departed  tt0407887
# 112016                                  Black-ish  tt3487356
# 112017                                  Black-ish  tt3487356
# 112018                                  Black-ish  tt3487356
# 112019                                  Black-ish  tt3487356
# 112020                                  Black-ish  tt3487356
# 112021                                       None       None
# 112022                                  Black-ish  tt3487356
# 112023                              Kangaroo Jack  tt0257568
# 112024                                  Black-ish  tt3487356
# 112025                                  Black-ish  tt3487356
# 112026                               The Departed  tt0407887
# 112027                                  Black-ish  tt3487356
# 112028                                  Black-ish  tt3487356
# 112029                                  Black-ish  tt3487356
# 112030                               The Departed  tt0407887
# 112031                              Hustle & Flow  tt0410097
# 112032                                  Black-ish  tt3487356
# 112033                                  Black-ish  tt3487356
# 112034                                  Black-ish  tt3487356
# 112035                                  Black-ish  tt3487356
# 112036                                  Black-ish  tt3487356
# 112037                                  Black-ish  tt3487356
# 112038                    All About the Andersons  tt0367276
# 112039                              Kangaroo Jack  tt0257568
# 112040                                 Barbershop  tt0303714
# 112041                                       None       None
# 112042                                     Rx 100  tt8665746
# 112043                                     Genèse  tt8287690
# 112044                                  Congorama  tt0810809
# 112045                                  Le marais  tt0332239
# 112046                  La moitié gauche du frigo  tt0260193
# 112047         Sunshine Sketches of a Little Town  tt2062657
# 112048                            Crossing Jordan  tt0284718
# 112049  Jackie, Ethel, Joan: The Women of Camelot  tt0247875
